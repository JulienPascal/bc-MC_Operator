# %% [markdown]
# # bc-MC consumption-savings problem: Large scale models

# %% [markdown]
# ## The model
#
# We consider the following consumption-saving problem:
#
# \begin{equation*}
# \begin{split}
# \max_{\{c_t\}_{t=0}^{\infty}} E\Big[ \sum_{t=0}^{\infty} \beta^t u(c_t) \exp(\delta_t)\Big]
# \end{split}
# \end{equation*}
# subject to the same constraints:
# $$
# \begin{gather*}
# \text{s.t. }w_{t+1}=\left( w_{t}-c_{t}\right) \overline{r}\exp (r_{t+1})+\exp
# (y_{t+1}), \\
# c_{t} \leq w_{t} + b
# \end{gather*}
# $$
#
# Total income $y_t$ is assumed to be stochastic, with $y_t = \exp(\sum_{i=1}^{l} p_{i,t})$. The model has $2+l$ exogenous variables, which we assume to follow AR(1) processes:
#
# \begin{equation}
# \begin{split}
# p_{i,t+1} & = \rho_{i,p} p_{i,t} + \sigma_{i,p} \varepsilon^{p}_{i,t+1}, \quad \forall i \in {1,2,...,l}\\
# r_{t+1} & = \rho_r r_t + \sigma_r \varepsilon^{r}_{t+1} \\
# \delta_{t+1} & = \rho_{\delta} \delta_t + \sigma_{\delta} \varepsilon^{\delta}_{t+1}
# \end{split}
# \end{equation}
#
#
# * The state is $3+l$-dimensional vector $s = \big(w, r, \delta, p_{1}, ..., p_{l}\big)$.
#
# * The shock is a $2+l$-dimensional vector $\varepsilon= \big(\varepsilon^{r}, \varepsilon^{\delta}\, \varepsilon^{p}_{1}, ..., \varepsilon^{p}_{l} \big)$
#
# The variable $c_{t}$ is consumption; $w_{t}$ is the beginning-of-period
# cash-on-hand; $\beta \in \left[ 0,1\right)$ is a subjective discount
# factor;  $\overline{r}\in \left( 0,\frac{1}{\beta }\right)$ is a (gross)
# constant interest rate; and initial condition $\left( z,w\right)$ is given.
# There is an occasionally binding inequality constraint: consumption $c_{t}$
# **CAN** exceed cash-on-hand $w_{t}$, because of borrowing.
#
#
# where $\epsilon^i_t \sim \mathcal{N}\left( 0,1\right)$. We assume the Cobb-Douglas utility function $u\left( {c_{t}}\right) =\frac{1}{1-\gamma }\left( c_{t}^{1-\gamma }-1\right)$.

# %% [markdown]
# ## Euler equation of the model
#
# Expectation is with respect to 4 shocks: $\varepsilon = (q, p, r, \delta)$
#
#
# $$
# \begin{gather*}
# \max\Big( \beta \overline{r}E_{\epsilon }\left[ \frac{u^{\prime }\left(
# c^{\prime }\right) }{u^{\prime }(c)}\exp \left(   \delta ^{\prime }-\delta
# +r^{\prime }\right)  \right], \frac{u'(w + b)}{u'(c)} \Big) - 1 = 0
# \end{gather*}
# $$
#
# Unit less measure of accuracy:
#
# $$
# \begin{gather*}
# 1 - \frac{1}{c} (u^{\prime})^{-1} \Big[\max \Big( \beta \overline{r}E_{\epsilon }\left[ u^{\prime }\left(
# c^{\prime }\right) \exp \left( \delta ^{\prime }-\delta
# +r^{\prime }\right), u^{\prime}(w + b) \Big) \right] = 0
# \end{gather*}
# $$
#
# ## ANN formulation
#
# The solution to this dynamic programming problems is characterized by the following Kuhn-Tucker conditions:
#
# \begin{equation}\label{eq:KT_BC}
# \begin{split}
# A \geq 0, H \geq 0, AH = 0 \\
# A \equiv w - c\\
# H \equiv u'(c) - \beta \bar{r} E_{\varepsilon} \Big[u'(c')\exp(\delta' + \delta - r')\Big]
# \end{split}
# \end{equation}
#
# The loss function for the ANN is:
#
# \begin{equation}
# \begin{split}
#     \mathcal{L}(\theta) & =  \mu_1 E_{s}\Big[  \Big(  E_{\varepsilon}\Big[\beta \bar{r} \frac{u'(c(s'|\theta))}{u(c(s|\theta))}\exp(\delta' + \delta - r') - h(s|\theta) \Big] \Big)^2 \Big] \\
#     & + \mu_2 \Big( E_{s} \Big[ \Psi\Big(1 - \frac{c(s|\theta)}{w}, 1 - h(s|\theta)\Big)^2 \Big] \Big)
#     \end{split}
# \end{equation}
#
#
# We use the Fischer-Burmeister (FB) function, defined by $\Psi(a, h) \equiv a + h - \sqrt{a^2 + h^2}$. The FB function is such that when it is equal to 0, the Kuhn-Tucker conditions are satisfied: $\Psi (a, h) = 0 \Leftrightarrow a \geq 0, h \geq 0, ah = 0 $ (see for instance Chen et al, 2000).
#
# Using the bc-MC estimator:
#
# \begin{equation}\label{eq:loss_function_bc_1}
# \begin{split}
#     \mathcal{L}^U_{M,N}(\theta) & =  \mu_1 \frac{2}{MN(N-1)} \sum_{m=1}^{M} \sum_{1 \leq i < j}^{N}  f(s_m,\epsilon^i_m|\theta) f(s_m,\epsilon^j_m|\theta) \\
#     & + \mu_2 \frac{1}{M} \sum_{m=1}^{M}   \Psi\Big(1 - \frac{c(s_m|\theta)}{w_m}, 1 - h(s_m|\theta)\Big)^2
# \end{split}
# \end{equation}
#
# with $f(s,\epsilon|\theta) \equiv \beta \bar{r} \frac{u'(c(s'|\theta))}{u(c(s|\theta))}\exp(\delta' + \delta - r') - h(s|\theta) $
#
# ## Structure of this notebook
#
# WIP

# %% [markdown]
# # 0. Dependencies
#
# You can use 'pip' to install dependencies.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import random
import scipy.stats
import chaospy  ## for quadrature
from itertools import product
import os

import tensorflow as tf
import time
import os
import pandas as pd
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
from tqdm import tqdm as tqdm         # tqdm is a nice library to visualize ongoing loops
import datetime
# followint lines are used for indicative typing
from typing import Tuple
class Vector: pass
from scipy.stats import norm
import Tasmanian
import torch
from torch import nn
from torch.utils.data import DataLoader
# To create copies of NN
import copy
import matplotlib.ticker as mtick
# To use sparse kronecker product
from scipy import sparse
from torchcontrib.optim import SWA
from torch.nn.utils import clip_grad_norm_
import itertools
# Interpolations
from scipy.interpolate import LinearNDInterpolator
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from scipy.interpolate import RegularGridInterpolator

# Regressions
import statsmodels.formula.api as smf
import statsmodels.api as sm
lowess = sm.nonparametric.lowess

import quantecon as qe
from interpolation import interp
from quantecon.optimize import brentq
from numba import njit, float64
from numba.experimental import jitclass
#import copy # Not used so far

import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
# Out:
# 2024-01-12 21:09:14.942196: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-12 21:09:14.942213: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Display version of python currently used
# !python3 --version
# Out:
# Python 3.8.10

# %%
# Display which version of packages I am using
# !pip freeze > requirements.txt
# !cat requirements.txt
# Out:
# absl-py==1.0.0
# aiodns==3.0.0
# aiohttp==3.8.3
# aiosignal==1.2.0
# alabaster==0.7.8
# altair==5.0.0
# appdirs==1.4.4
# apturl==0.5.2
# argon2-cffi==21.1.0
# arviz==0.15.1
# astunparse==1.6.3
# async-generator==1.10
# async-timeout==4.0.1
# attrs==21.2.0
# autograd==1.6.2
# Babel==2.6.0
# backcall==0.2.0
# backports.zoneinfo==0.2.1
# bcrypt==3.1.7
# beautifulsoup4==4.12.2
# bleach==4.1.0
# blinker==1.4
# bokeh==2.4.2
# bottle==0.12.19
# branca==0.4.2
# Brlapi==0.7.0
# Brotli==1.0.9
# bs4==0.0.1
# cached-property==1.5.1
# cachetools==4.2.4
# cattrs==1.9.0
# cchardet==2.1.7
# ccsm==0.9.14.1
# certifi==2019.11.28
# cffi==1.15.0
# chaospy==4.3.8
# chardet==3.0.4
# charset-normalizer==2.0.7
# chrome-gnome-shell==0.0.0
# Click==7.0
# click-plugins==1.1.1
# cligj==0.7.2
# cloudpickle==3.0.0
# cmake==3.21.4
# cmasher==1.6.3
# colorama==0.4.3
# colorspacious==1.1.2
# command-not-found==0.3
# compizconfig-python==0.9.14.1
# conan==1.42.1
# contourpy==1.0.7
# corner==2.2.1
# cryptography==2.8
# cupshelpers==1.0
# cycler==0.11.0
# DateTime==4.3
# dblatex===0.3.11py3
# DBnomics==1.2.3
# dbus-python==1.2.16
# debugpy==1.5.1
# decorator==5.1.0
# defer==1.0.6
# defusedxml==0.7.1
# dell-recovery==0.0.0
# deprecat==2.1.1
# descartes==1.1.0
# dill==0.3.6
# distlib==0.3.0
# distro==1.4.0
# distro-info==0.23+ubuntu1.1
# dnspython==1.16.0
# docker==4.1.0
# docker-compose==1.25.0
# dockerpty==0.4.1
# docopt==0.6.2
# docutils==0.16
# dolang==0.0.14
# duplicity==0.8.12.0
# e13tools==0.9.6
# emcee==3.1.4
# entrypoints==0.3
# et-xmlfile==1.1.0
# evdev==1.6.1
# fastcore==1.3.27
# fasteners==0.14.1
# fastprogress==1.0.0
# fear-and-greed==0.1
# fear-greed-index==0.1.3
# feedparser==5.2.1
# filelock==3.0.12
# Fiona==1.8.21
# fitdecode==0.10.0
# fix-yahoo-finance==0.1.37
# flatbuffers==2.0
# folium==0.12.1.post1
# fonttools==4.39.3
# frozendict==2.3.8
# frozenlist==1.2.0
# fsspec==2023.10.0
# future==0.18.2
# fuzzymatcher==0.0.6
# fuzzywuzzy==0.18.0
# gast==0.4.0
# GDAL==3.4.3
# geographiclib==1.52
# geojson==2.5.0
# geopandas==0.10.2
# geopy==2.2.0
# glcontext==2.3.4
# google-auth==2.3.3
# google-auth-oauthlib==0.4.6
# google-pasta==0.2.0
# gpg==1.13.1
# graphviz==0.20
# greenlet==2.0.2
# grpcio==1.42.0
# guacamole==0.9.2
# gunicorn==20.0.4
# h11==0.13.0
# h5netcdf==1.1.0
# h5py==3.6.0
# haversine==2.5.1
# html5lib==1.1
# httplib2==0.14.0
# humanize==3.12.0
# idna==2.8
# imageio==2.16.0
# imagesize==1.2.0
# import-ipynb==0.1.4
# importlib-metadata==1.5.0
# importlib-resources==5.12.0
# interpolation==2.2.1
# ipykernel==6.5.0
# ipynb==0.5.1
# ipython==7.29.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.4
# jedi==0.18.0
# Jinja2==2.10.1
# joblib==1.1.0
# jsonschema==3.2.0
# jupyter-client==7.0.6
# jupyter-core==4.9.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==3.0.5
# kazam==1.4.5
# keras==2.7.0
# Keras-Preprocessing==1.1.2
# keyring==18.0.1
# kiwisolver==1.3.2
# language-selector==0.1
# lark==0.10.1
# lark-parser==0.9.0
# launchpadlib==1.10.13
# lazr.restfulclient==0.14.2
# lazr.uri==1.0.3
# Levenshtein==0.21.1
# libclang==12.0.0
# llvmlite==0.37.0
# lockfile==0.12.2
# louis==3.12.0
# lxml==4.9.3
# m2r2==0.2.8
# macaroonbakery==1.3.1
# Mako==1.1.0
# Markdown==3.1.1
# MarkupSafe==1.1.0
# matplotlib==3.7.1
# matplotlib-inline==0.1.3
# Metaphone==0.6
# mistune==0.8.4
# mizani==0.7.3
# moderngl==5.6.4
# monotonic==1.5
# more-itertools==4.2.0
# mplfinance==0.12.7a17
# mpmath==1.2.1
# mpu==0.23.1
# multidict==5.2.0
# multipledispatch==0.6.0
# multitasking==0.0.9
# munch==2.5.0
# mycolorpy==1.5.1
# nbclient==0.5.8
# nbconvert==6.3.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# netifaces==0.10.4
# networkx==3.0
# node-semver==0.6.1
# notebook==6.4.5
# numba==0.54.1
# numpoly==1.2.3
# numpy==1.20.3
# nvidia-cublas-cu11==11.10.3.66
# nvidia-cublas-cu12==12.1.3.1
# nvidia-cuda-cupti-cu12==12.1.105
# nvidia-cuda-nvrtc-cu11==11.7.99
# nvidia-cuda-nvrtc-cu12==12.1.105
# nvidia-cuda-runtime-cu11==11.7.99
# nvidia-cuda-runtime-cu12==12.1.105
# nvidia-cudnn-cu11==8.5.0.96
# nvidia-cudnn-cu12==8.9.2.26
# nvidia-cufft-cu12==11.0.2.54
# nvidia-curand-cu12==10.3.2.106
# nvidia-cusolver-cu12==11.4.5.107
# nvidia-cusparse-cu12==12.1.0.106
# nvidia-nccl-cu12==2.18.1
# nvidia-nvjitlink-cu12==12.3.101
# nvidia-nvtx-cu12==12.1.105
# oauthlib==3.1.0
# odfpy==1.4.1
# olefile==0.46
# onboard==1.4.1
# openai==0.26.5
# openpyxl==3.0.9
# opt-einsum==3.3.0
# outcome==1.1.0
# OWSLib==0.25.0
# packaging==23.1
# padme==1.1.1
# palettable==3.3.0
# pandas==2.0.3
# pandas-datareader==0.10.0
# pandas-geojson==1.2.0
# pandocfilters==1.5.0
# paramiko==2.6.0
# parso==0.8.2
# patch-ng==1.17.4
# path==16.2.0
# patsy==0.5.2
# pexpect==4.6.0
# pickleshare==0.7.5
# Pillow==8.4.0
# pipreqs==0.4.13
# plotly==5.10.0
# plotnine==0.8.0
# pluginbase==1.0.1
# probscale==0.2.5
# progressbar==2.5
# prometheus-client==0.12.0
# prompt-toolkit==3.0.22
# protobuf==3.19.1
# proton-client==0.7.1
# protonvpn-cli==3.13.0
# protonvpn-gui==1.12.0
# protonvpn-nm-lib==3.16.0
# psutil==5.5.1
# psycopg2==2.9.2
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycairo==1.16.2
# pycares==4.3.0
# pycparser==2.21
# pycups==1.9.73
# pycurl==7.43.0.2
# pyDOE2==1.3.0
# pydot==1.4.2
# Pygments==2.10.0
# PyGObject==3.36.0
# PyJWT==1.7.1
# pymacaroons==0.13.0
# pymc3==3.11.5
# PyNaCl==1.3.0
# pynput==1.7.6
# pyOpenSSL==19.0.0
# pyparsing==2.4.6
# pyproj==3.3.1
# PyQt5==5.14.1
# pyRFC3339==1.1
# pyro-api==0.1.2
# pyro-ppl==1.8.6
# pyrr==0.10.3
# pyrsistent==0.15.5
# pysg==0.1.5
# python-apt==2.0.1+ubuntu0.20.4.1
# python-dateutil==2.8.2
# python-debian==0.1.36+ubuntu1.1
# python-gnupg==0.4.5
# python-Levenshtein==0.21.1
# python-xlib==0.33
# pythondialog==3.4.0
# pytrends==4.7.3
# pytz==2023.3
# pytz-deprecation-shim==0.1.0.post0
# pyxdg==0.26
# PyYAML==5.3.1
# pyzmq==22.3.0
# quantecon==0.4.8
# rapidfuzz==3.2.0
# reportlab==3.5.34
# requests==2.31.0
# requests-cache==0.8.1
# requests-oauthlib==1.3.0
# requests-unixsocket==0.2.0
# retrying==1.3.3
# roman==2.0.0
# rpy2==3.4.5
# rsa==4.8
# sas7bdat==2.2.3
# scikit-build==0.13.1
# scikit-learn==1.0.1
# scipy==1.10.1
# screen-resolution-extra==0.0.0
# seaborn==0.12.2
# SecretStorage==2.3.1
# selenium==4.1.0
# semver==3.0.0
# Send2Trash==1.8.0
# sequence-jacobian==1.0.0
# Shapely==1.8.1.post1
# simplejson==3.16.0
# sip==4.19.21
# six==1.14.0
# sklearn==0.0
# smt==2.0
# sniffio==1.2.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soupsieve==1.9.5
# Sphinx==4.3.1
# sphinx-rtd-theme==0.5.2
# sphinxcontrib-applehelp==1.0.2
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# SQLAlchemy==2.0.11
# statsmodels==0.13.5
# style==1.1.0
# sympy==1.9
# system-service==0.3
# systemd-python==234
# tabulate==0.9.0
# Tasmanian==7.7
# Tempita==0.5.2
# tenacity==8.0.1
# tensorboard==2.7.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.0
# tensordict==0.2.1
# tensorflow==2.7.0
# tensorflow-estimator==2.7.0
# tensorflow-io-gcs-filesystem==0.22.0
# termcolor==1.1.0
# terminado==0.12.1
# testpath==0.5.0
# texttable==1.6.2
# Theano-PyMC==1.1.2
# threadpoolctl==3.0.0
# toolz==0.12.0
# torch==2.1.1
# torch-lr-finder==0.2.1
# torchcontrib==0.0.2
# torchdiffeq==0.2.2
# torchmetrics==0.10.2
# torchrl==0.2.1
# torchvision==0.14.1
# torchviz==0.0.2
# tornado==6.1
# tqdm==4.62.3
# traitlets==5.1.1
# trio==0.19.0
# trio-websocket==0.9.2
# triton==2.1.0
# typing-extensions==4.5.0
# tzdata==2023.3
# tzlocal==4.1
# ubuntu-advantage-tools==8001
# ubuntu-drivers-common==0.0.0
# ufw==0.36
# unattended-upgrades==0.1
# unity-scope-calculator==0.1
# unity-scope-devhelp==0.1
# unity-scope-gdrive==0.7
# unity-scope-manpages==0.1
# unity-scope-texdoc==0.1
# unity-scope-tomboy==0.1
# unity-scope-virtualbox==0.1
# unity-scope-zotero==0.1
# update==0.0.1
# url-normalize==1.4.3
# urllib3==1.26.7
# usb-creator==0.3.7
# v==0.0.0
# vboxapi==1.0
# virtualenv==20.0.17
# wadllib==1.3.3
# wcwidth==0.2.5
# webencodings==0.5.1
# websocket-client==0.53.0
# Werkzeug==2.0.2
# wget==3.2
# widgetsnbextension==4.0.5
# wordcloud==1.8.1
# wrapt==1.13.3
# wsproto==1.0.0
# xarray==2023.1.0
# xarray-einstats==0.5.1
# xdiagnose==3.8.9
# xitorch==0.5.1
# xkit==0.0.0
# XlsxWriter==1.1.2
# yarg==0.1.9
# yarl==1.7.2
# yfinance==0.2.28
# zipp==3.15.0

# %%
# Import functions from a notebook
# %run functions-bc-MC-consumption-savings.ipynb
# Set default figsize
plot_scale = 1.25
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)
# Controlling fontsizes
SMALL_SIZE = 12
MEDIUM_SIZE = SMALL_SIZE + 2
BIGGER_SIZE =  SMALL_SIZE + 4
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
dpi_chosen=600 #control the quality of .png
linewidth_chosen = 2
# Out:
# Using cpu device

# %%
### Important options for the code
# Run benchmark. Can be time-consuming
benchmark_TI = True 
benchmark_TI_sparse = True 
benchmark_TI_a_sparse = True 
benchmark_MC = True 

# Save and load files
save_csv_file_TI = True #When testing time-accuracy, save results to .csv
save_csv_file_TI_sparse = True #When testing time-accuracy, save results to .csv
save_csv_file_TI_a_sparse = True #When testing time-accuracy, save results to .csv
save_csv_file_MC = True #When testing time-accuracy, save results to .csv

load_csv_file_TI = True #When testing time-accuracy, save results to .csv
load_csv_file_TI_sparse = True #When testing time-accuracy, save results to .csv
load_csv_file_TI_a_sparse = True #When testing time-accuracy, save results to .csv
load_csv_file_MC = True #When testing time-accuracy, save results to .csv

# Nb draws accuracy benchmark
nb_draws_gaussian = 5000

# %%
seed_number = 1234
random.seed(seed_number) # For replicability reasons
print(random.random())
# Out:
# 0.9664535356921388

# %%
current_wd = os.getcwd() 
output_folder = current_wd  + "/output/"
# Create folder if does not exist:
if not os.path.exists(output_folder):
    # If it doesn't exist, create it
    os.makedirs(output_folder)

# %%
distrib = chaospy.J(chaospy.Normal(0, 1))
nodes, weights = dist(1, distrib, rule = "gaussian", sp=True)
nodes.shape
# Out:
# (1, 2)

# %%
# Store parameters
class MyParams():
    """
    N: number of draws for innovation vector
    M: number of draws for the state vector
    lr: learning rate
    pre_train_model: whether or not pre-train the model before starting the full training loop (not used)
    nb_epochs: number of gradient descent steps during training
    bc: borrowing constraint 
    order_gauss: order for the Gaussian quadrature to use when solving with time iteration
    σ_shocks: parameter determining the variance of shocks
    use_Sobol: whether or not use Sobol sampling for the state stapce
    dim_p: number of different pi
    grid_depth: depth of the sparse grid
    nb_refinements: nb refinement for the adaptive sparse grid
    surplus_threshold: surplus threshold to use for the adaptive sparse grid
    name_params: name of params object initialized
    nb_points_w: nb grid points for w grid
    nb_points_other: nb grid points other dimensions
    w1: weight first element loss function
    w2: weight second element loss function
    debug: if True, print info on params when building it
    """
    def __init__(self, N, M, lr, pre_train_model, nb_epochs, 
                 bc, order_gauss, σ_shocks, use_Sobol, 
                 optimizer, dim_p,
                 grid_depth, nb_refinements, surplus_threshold,
                 name_params,
                 nb_points_w=10, nb_points_other=3, 
                 w1 = 0.5, w2 = 0.5,
                 debug=False):
        # savings-consumption with binding constraint
        # Model parameters
        self.β = 0.9 
        self.γ = 2.0
        self.one_min_γ = 1 - self.γ
        self.σ_shocks = σ_shocks #default 0.01
        self.σ_r = self.σ_shocks #0.01
        self.ρ_r = 0.9 #0.2
        self.σ_δ = self.σ_shocks
        self.ρ_δ = 0.9 #0.2
        self.σ_p = self.σ_shocks
        self.ρ_p = 0.9 
        self.rbar = 1.04
        # Level of borrowing constraint
        if isinstance(bc, (int, float)):
            self.bc = bc
            self.bc_torch = torch.tensor([self.bc])
        else:
            raise TypeError("bc_chosen must be a real number (int or float).")       
        # Standard deviations for ergodic distributions of exogenous state variables
        self.σ_e_r = self.σ_r/(1-self.ρ_r**2)**0.5
        self.σ_e_δ = self.σ_δ/(1-self.ρ_δ**2)**0.5
        self.σ_e_p = self.σ_p/(1-self.ρ_p**2)**0.5
        # grids
        self.dim_p = dim_p #(p1, p2, ..., pl)
        self.dim_state = 3 + dim_p #(w ,r, delta, p1, p2, ..., pl)
        self.dim_shock = 2 + dim_p #(e_r, e_delta, e_p1, e_p2, ..., e_pl)
        self.n_points_grid = nb_points_other #nb points for (r, δ, p1, ..., pl)
        self.n_points_w = nb_points_w #10 #nb points for w
        self.r_min = -2*self.σ_e_r 
        self.r_max = 2*self.σ_e_r 
        self.δ_min = -2*self.σ_e_δ
        self.δ_max = 2*self.σ_e_δ
        self.p_min = -2*self.σ_e_p
        self.p_max = 2*self.σ_e_p 
        # bounds for endogenous state variable (cash-in-hand)
        self.wmin = 0.001 #0.1 #4 stdev with bc =0, based on TI. 0.7752188662883139 - 1.3681603157252489
        self.wmax = 3.0 #4.0
        self.w_grid = np.linspace(self.wmin, self.wmax, self.n_points_w)
        self.r_grid = np.linspace(self.r_min, self.r_max, self.n_points_grid)
        self.δ_grid = np.linspace(self.δ_min, self.δ_max, self.n_points_grid)
        self.p_grid = np.linspace(self.p_min, self.p_max, self.n_points_grid)
        # generate a tensor product grid
        # order: w, r, delta, p1, p2, ..., pn
        strr = "self.w_grid, self.r_grid, self.δ_grid"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "self.p_grid"
        if debug==True:
            print("Tensor product grid build with: {}".format(strr)) #debug
        self.wrδ_ps_grid = eval('list(itertools.product({}))'.format(strr))
        # Generate a grid for indices along each dimension
        self.indices_w = range(self.n_points_w)
        self.indices_r = range(self.n_points_grid)
        self.indices_δ = range(self.n_points_grid)
        self.indices_p = range(self.n_points_grid)
        # order: w, r, delta, p1, p2, ..., pn
        strr = "self.indices_w, self.indices_r, self.indices_δ"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "self.indices_p"
        self.wrδ_ps_indices = eval('list(itertools.product({}))'.format(strr))
        # Functions
        self.u = lambda c: (1/self.one_min_γ)*(c**(self.one_min_γ) - 1)
        self.u_prime =  lambda c: c**(-self.γ)
        self.u_prime_inv =  lambda c: c**(-(1/self.γ))
        # Standard shocks
        σ_e = 0.5 #
        μ_e = 0.0 #location parameter shocks
        # Values passed as inputs
        self.N = N #number of draws inside expectation
        self.M = M #number of draws outside expecation
        self.MN = int(M*N)
        # To keep constant the number of function evaluations
        self.T = int((M*N)/2) #number of draws all in on expectation
        # To compare Loss functions
        #self.T = int((M*N)) #number of draws all in on expectation
        self.x_distribution = "Uniform" #"Normal" #Uniform or Normal
        self.σ_e = σ_e
        self.μ_e = μ_e
        self.e_distribution = "Lognormal" #"Normal"
        self.x_low = self.wmin
        self.x_high = self.wmax
        # Vectorized Monte Carlo requires the creation of some objects
        # To repeat vectors
        repeat_vector = torch.ones(N) #to repeat the same value n times using a matrix multiplication
        # To calculate the expectation wrt future shocks using a matrix multiplication
        A = sparse.eye(M) 
        B = sparse.csr_matrix(np.ones(N)/N)
        # Sparse kronecker product. Then convert to pytorch sparse
        # W used using the sum((sum)^2) formula
        W = sparse_mx_to_torch_sparse_tensor(sparse.kron(A, B))
        self.repeat_vector = repeat_vector
        self.W = W  
        # W used using the 2/N(N-1) sum() formula
        self.W_expanded = create_W_expanded_matrix(self.M, self.N)
        # Learning parameters
        self.lr = lr
        self.momentum = 0.9 #momentum for SGD with momentum
        self.lr_pre_train = 1e-3 #learning rate during pre-training
        self.optimizer = optimizer #"Adam" #default: #Adam or SGD or SWA
        self.freq_gamma = 0.95 #0.85
        self.use_scheduler = False #default: True
        self.pre_train_model = pre_train_model #default: True
        self.nb_epochs = nb_epochs
        self.nb_epochs_pre_train = int(self.nb_epochs/1)
        self.freq_scheduler = 1000 #int(self.nb_epochs/10)
        # Sobol sampling
        self.soboleng = torch.quasirandom.SobolEngine(dimension=1) #sobol draws for income
        self.use_Sobol = use_Sobol #Sobol for dimension M
        self.use_Sobol_T = use_Sobol #Sobol for all-in-one
        # DEBUG PARAMS
        self.error_correction=True #error correction for the model
        self.selective_error_correction=False #error correction for the model, only if give positive values
        self.abs_value=False
        self.perfect_forecast = False
        self.fake_bias=0.0
        # GAUSSIAN QUADRATURE
        # value e_r, e_δ, e_p1, e_p2, ..., e_pl
        strr = "chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ)"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "chaospy.Normal(0, self.σ_p)"
        if debug==True:
            print("Quadrature grid build for: {}".format(strr)) #debug
        self.distrib = eval('chaospy.J({})'.format(strr))
        #self.distrib = chaospy.J(chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ), chaospy.Normal(0, self.σ_p))
        self.order_gauss = order_gauss
        nodes, weights = dist(self.order_gauss, self.distrib, rule = "gaussian", sp=True)
        self.nodes = nodes
        self.weights = weights
        self.weights_torch = torch.tensor(weights)
        self.nodes_torch = torch.tensor(np.transpose(self.nodes)) #column=dim. Row=observation
        # Save the number of points for the guassian quadrature:
        self.N_gaussian = len(self.weights_torch)
        # Implied number of points for the current space (T=MN/2 <-> M = 2T/N)
        self.M_gaussian = int((2*self.T)/self.N_gaussian)
        self.MN_gaussian = self.N_gaussian*self.M_gaussian
        # Repeat nodes to match the number of function evaluations for the expectation
        self.nodes_torch_repeated = self.nodes_torch.repeat(self.M_gaussian, 1)
        # CREATE A W MATRIX FOR GAUSSIAN QUADRATURE:
        B_gaussian = sparse.csr_matrix(self.weights_torch)
        # Sparse kronecker product. Then convert to pytorch sparse
        A_gaussian = sparse.eye(self.M_gaussian) 
        self.W_gaussian = sparse_mx_to_torch_sparse_tensor(sparse.kron(A_gaussian, B_gaussian))
        # SCALE OF THE OBJECTIVE FUNCTION
        self.nb_points_test = 1000
        self.xvec_test_torch = torch.linspace(self.x_low, self.x_high, self.nb_points_test).unsqueeze(1) #add a dimension
        self.xvec_test = self.xvec_test_torch.numpy()
        self.swa_start = 1000
        self.swa_freq= 10
        # To measure accuracy during training
        self.M_accuracy = 5000
        self.N_accuracy = 100
        self.MN_accuracy = int(self.M_accuracy*self.N_accuracy)
        self.repeat_vector_accuracy = torch.ones(self.N_accuracy)
        # Sparse version        
        A = sparse.eye(self.M_accuracy)
        B = sparse.csr_matrix(np.ones(self.N_accuracy)/self.N_accuracy)
        # Sparse kronecker product. Then convert to pytorch sparse
        self.W_accuracy = sparse_mx_to_torch_sparse_tensor(sparse.kron(A, B))
        # randomly drawing current states
        self.r_accuracy = torch.normal(mean=0, std=self.σ_e_r, size=(self.M_accuracy,)) 
        self.δ_accuracy = torch.normal(mean=0, std=self.σ_e_δ, size=(self.M_accuracy,)) 
        # dimension (M, dim_p)
        self.p_accuracy = torch.normal(mean=0, std=self.σ_e_p, size=(self.M_accuracy, dim_p)) 
        #w = (params.wmin - params.wmax) * torch.rand(n) + params.wmax #uniform
        w = (self.wmin - self.wmax) * self.soboleng.draw(self.M_accuracy) + self.wmax #uniform
        self.w_accuracy = w.squeeze(1)
        # n_Monte_Carlo for each value today
        self.e_r_accuracy = torch.normal(mean=0, std=self.σ_r, size=(self.MN_accuracy,)) 
        self.e_δ_accuracy = torch.normal(mean=0, std=self.σ_δ, size=(self.MN_accuracy,)) 
        self.e_p_accuracy = torch.normal(mean=0, std=self.σ_p, size=(self.MN_accuracy, dim_p)) 
        #
        self.r_repeated_accuracy = torch.kron(self.r_accuracy, self.repeat_vector_accuracy)
        self.δ_repeated_accuracy = torch.kron(self.δ_accuracy, self.repeat_vector_accuracy)
        self.w_repeated_accuracy = torch.kron(self.w_accuracy, self.repeat_vector_accuracy)
        # dimension (MN, dim_p))
        self.p_repeated_accuracy = self.p_accuracy.repeat_interleave(self.N_accuracy, dim=0) #repeat N times
        # transitions of the exogenous processes
        #r = torch.normal(mean=0, std=σ_e_r, size=(n,)) 
        #torch.kron(r, repeat_vector).shape
        self.rnext_accuracy = self.r_repeated_accuracy*self.ρ_r + self.e_r_accuracy
        self.δnext_accuracy = self.δ_repeated_accuracy*self.ρ_δ + self.e_δ_accuracy
        self.pnext_accuracy = self.p_repeated_accuracy*self.ρ_p + self.e_p_accuracy
        # For the next period, the sum of p1, p2, ... , pl matter
        self.pnext_sum_accuracy = torch.sum(self.pnext_accuracy, axis=1) #sum over rows
        # To store the solution of time iteration
        # Order of the loop: w, r, delta, p1, p2, ..., pn
        strr = "self.n_points_w, self.n_points_grid, self.n_points_grid"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "self.n_points_grid"
        if debug==True:
            print("Grid to store TI values: {}".format(strr)) #debug
        self.c_grid_TI = eval('np.zeros(({}))'.format(strr))
        # Order of the loop: w, r, delta, p1, p2, ..., pn
        strr = f"{name_params}.n_points_w, {name_params}.n_points_grid, {name_params}.n_points_grid"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + f"{name_params}.n_points_grid"
        self.str_nb_points = strr
        # Order of the loop: w, r, delta, p1, p2, ..., pn
        strr = f"{name_params}.w_grid, {name_params}.r_grid, {name_params}.δ_grid"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + f"{name_params}.p_grid"
        strr = strr + "," + "σ, x"
        self.str_c_grid_TI = strr
        if debug==True:
            print("Grid for c_grid_TI: {}".format(self.str_c_grid_TI)) #debug
        exec('self.c_function_TI = lambda x: interp({})'.format(strr))
        # For evaluations with a function
        strr = f"{name_params}.w_grid, {name_params}.r_grid, {name_params}.δ_grid"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + f"{name_params}.p_grid"
        strr = strr + "," + "σ_local, x"
        self.str_c_grid_TI_local = strr
        def identity_function(x):
            return x
        self.c_function_TI = identity_function #Initialization TI solution, interpolated
        self.ss = np.ones(self.dim_state) #steady-state value
        # Parameters for the adaptive sparse grid
        self.grid_depth = grid_depth # Initial depth of the sparse grid
        self.nb_refinements = nb_refinements # Nb of refinement steps for the sparse grid
        self.surplus_threshold = surplus_threshold #
        self.grid_dim = 3 + self.dim_p # Dimension input: (w, r, delta, vector ps)
        self.grid_out = 1 # Dimension output
        self.grid_order = 1 #1 # 1=linear, 2=quadratic, 3=cubic
        self.grid_rule = "localp" # Type of base functions
        # Need to set the domain
        ## 2 columns: min, max
        ## rows: corresponding to a variable
        ## Order: w, r, delta, p1, p2, ..., pn
        self.domain_transform = np.zeros((self.grid_dim, 2))
        self.domain_transform[0,:] = np.array([self.wmin, self.wmax])
        self.domain_transform[1,:] = np.array([self.r_min, self.r_max])
        self.domain_transform[2,:] = np.array([self.δ_min, self.δ_max])
        # max and min for the ps:
        self.domain_transform[3:,:] = np.array([self.p_min, self.p_max])
        # Store grid that is updating during time iteration
        self.grid_old = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth, self.grid_order, self.grid_rule)
        self.grid_old.setDomainTransform(self.domain_transform)
        self.grid_old_points = self.grid_old.getPoints() # Points of the grid
        # Let's store another grid to test for convergence of the time iteration algo
        self.grid_depth_test = 2
        self.grid_test = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth_test, self.grid_order, self.grid_rule)
        self.grid_test.setDomainTransform(self.domain_transform)
        self.grid_test_points = self.grid_old.getPoints()
        # To store sparse solution
        self.c_grid_TI_sparse = np.zeros((self.grid_old_points.shape[0],1))
        self.c_function_TI_sparse = identity_function # Initialization TI solution, using sparse grid
        # weights in the loss function
        self.w1 = w1
        self.w2 = w2
        # Check bad combination
        if (self.optimizer == "SWA") & (self.use_scheduler == True):
            raise('opt SWA and use_schedule = True')

# %%
M_chosen = 100 #25 #100 #200 # 50 #outer expectation 
N_chosen = 2 #8 #2 #4 # Inner expectation
lr_chosen = 1e-3 #0.5e-2
pre_train_model_chosen = False
nb_epochs_chosen = 10000
order_gauss = 1 #2 #Default. order_gauss = 2
bc_chosen = 0 #1.0 #0.0 #1.0
σ_shocks_chosen = 0.01
use_Sobol_chosen = False
optimizer_chosen = "Adam"
dim_p_chosen =  2 #Default is 2 (p and q, as in section 4.2)
# Parameters for the sparse grid
grid_depth_chosen = 3
nb_refinements_chosen = 2
surplus_threshold_chosen = 1e-4
name_params = "params_TI"
w1_chosen = 0.5
w2_chosen = 0.5

# REMARK:
# for the dense grid, to change the number of points on w-grid, change self.n_points_w = 10 
# to change the number of points for the other dimensions, change self.n_points_grid = 3
params_TI = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                  nb_epochs_chosen, bc_chosen, order_gauss,
                  σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                  dim_p_chosen, grid_depth_chosen, nb_refinements_chosen, surplus_threshold_chosen, 
                  name_params, nb_points_w=10, nb_points_other=3,
                  w1 = w1_chosen, w2 = w2_chosen)

show_params(params_TI)
# Out:
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# /tmp/ipykernel_10100/2656475211.py:8: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:605.)
#   return torch.sparse.FloatTensor(indices, values, shape)

# %% [markdown]
# ---
# ---
#
# # I. Time iteration solution
#
# ## I.A Time iteration solution on dense grid

# %% [markdown]
# Iterate over the Euler equation of the model:
#
# $$
# \begin{gather*}
# u^{\prime }(c) = \beta \overline{r}E_{\epsilon }\left[ u^{\prime }\left(
# c^{\prime }\right) \exp \left(   \delta ^{\prime }-\delta
# +r^{\prime }\right)  \right]
# \end{gather*}
# $$
#
# $$ c(w_t, y_t, p_t, r_t, \delta_t) $$

# %%
# Initial guess for time iteration
# initialize empty array
exec("σ = np.zeros(({}))".format(params_TI.str_nb_points))
print("Shape array: {}".format(σ.shape))

# Loop over values and indices
# Order:  w, r, delta, p1, p2, ..., pn
for (counter, (indices, vals)) in enumerate(zip(params_TI.wrδ_ps_indices, params_TI.wrδ_ps_grid)):
    w_value = vals[0]
    σ[indices] = 0.9*w_value
    
# Interpolate
σ_func =  eval('lambda x: interp({})'.format(params_TI.str_c_grid_TI))
σ_func(np.array(vals) + 1)
# Out:
# Shape array: (10, 3, 3, 3, 3)
# 2.7

# %%
# %%time
tol=0.0001
max_iter=100
verbose=True
print_skip = 10
i = 0
error = tol + 1

while i < max_iter:
    σ_new = K_quadrature(σ, σ_func, params_TI)
    error = np.max(np.abs(σ - σ_new))
    i += 1
    if verbose and i % print_skip == 0:
        print(f"Error at iteration {i} is {error}.")
    σ = σ_new
    
    #Create function by interpolation
    σ_func_TI = eval('lambda x: interp({})'.format(params_TI.str_c_grid_TI))
        
    if (error < tol) or (i == max_iter):
        if (error < tol):
            print("Convergence reached after {} iterations".format(i))
        if (i == max_iter):
            print("Convergence NOT reached after {} iterations".format(i))
        params_TI.c_grid_TI = copy.deepcopy(σ)
        params_TI.c_function_TI = copy.deepcopy(σ_func_TI)
        break
# Out:
# Error at iteration 10 is 0.007400591996223227.
# Convergence reached after 19 iterations
# CPU times: user 7.13 s, sys: 6.97 ms, total: 7.13 s
# Wall time: 7.13 s

# %%
# Plot the result
len_wec = params_TI.nb_points_test

with torch.no_grad():
    rvec = 0.0*np.ones(len_wec) #np.zeros(len_wec)
    δvec = 0.0*np.ones(len_wec) #np.zeros(len_wec)
    wvec = params_TI.xvec_test

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen))))
    
    cvec_TI = params_TI.c_function_TI(state_next) #σ_func(state_next)
    # Save for latter use
    cvec_TI_bc_0 = cvec_TI.copy()
    k_next_TI = wvec.squeeze(1) - cvec_TI
    k_next_TI_bc_0 = k_next_TI.copy()
    wgrid_TI_dense_bc_0  = params_TI.w_grid.copy()

plt.plot(wvec, wvec, linestyle='--', color='black')
plt.plot(wvec, cvec_TI, label='c TI')
plt.plot(wvec, k_next_TI, label='kt+1 TI')
plt.xlabel("$w_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Dense Grid")
plt.legend()
plt.show()

# Plot the result
len_wec = params_TI.nb_points_test

with torch.no_grad():
    rvec = np.linspace(params_TI.r_min, params_TI.r_max, len_wec)
    δvec = np.zeros(len_wec)
    wvec = np.ones(len_wec)

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI = params_TI.c_function_TI(state_next) #σ_func(state_next)
    k_next_TI = wvec - cvec_TI

#plt.plot(rvec, rvec, linestyle='--', color='black')
plt.plot(rvec, cvec_TI, label='c TI', color="blue", linestyle="dashdot")
#plt.plot(rvec, k_next_TI, label='kt+1 TI', color="green", linestyle="dashdot")
plt.xlabel("$r_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Dense Grid")
plt.legend()

# %% [markdown]
# ### Accuracy Time Iteration solution
#
# Uses Monte Carlo Integration to approximate the expectation with respect to next period's shocks.

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC(1000, 1000, params_TI)

print("Euler TI Dense Grid")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI Dense Grid")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./100)
plt.scatter(w, euler_bis, alpha=0.1)
plt.scatter(params_TI.w_grid, np.zeros(params_TI.n_points_w), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
# Out:
# Euler TI Dense Grid
# Mean: 0.005707611994247323
# Median: 0.001747444956085309
# Min: 7.741673968553187e-11
# Max: 0.06979229303541934
# std dev.: 0.01075982248813164
#
# Euler Bis TI Dense Grid
# Mean: 0.002909234195416411
# Median: 0.0008737202786757159
# Min: 3.8708480865068395e-11
# Max: 0.03683591730142899
# std dev.: 0.005571646101453068

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian(2000, params_TI)

print("Euler TI Dense Grid")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI Dense Grid")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./50)
plt.scatter(w, euler_bis, alpha=0.1)
plt.scatter(params_TI.w_grid, np.zeros(params_TI.n_points_w), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
# Out:
# Euler TI Dense Grid
# Mean: 0.005771072306433153
# Median: 0.001841586954901775
# Min: 1.335791477430348e-10
# Max: 0.08224656104074435
# std dev.: 0.011288238163181034
#
# Euler Bis TI Dense Grid
# Mean: 0.002944598560206413
# Median: 0.0009220672244460992
# Min: 6.67895738715174e-11
# Max: 0.04384734209776453
# std dev.: 0.005858303699082393

# %% [markdown]
# ## Modify dimension of state and innovation vectors

# %%
list_dim_p = list(range(1, 7)) #Test
#list_dim_p = list(range(1, 9)) #Version for the paper: very slow. THe last iter takes 7h30...
list_elapsed_time_TI = []
list_median_euler_error = []
list_mean_euler_error = []

# TI parameters
tol=0.0001
max_iter=100
verbose=True
print_skip = 10

if benchmark_TI == True:
    print("Benchmarking TI")
    for dim_p in tqdm(list_dim_p):
        start = time.time()

        # 0. Params
        #----------------------------------
        w1_chosen = 0.5
        w2_chosen = 0.5
        name_params = "params"
        params = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                          nb_epochs_chosen, bc_chosen, order_gauss,
                          σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                          dim_p, grid_depth_chosen, nb_refinements_chosen, surplus_threshold_chosen, 
                          name_params, nb_points_w=10, nb_points_other=3,
                          w1 = w1_chosen, w2 = w2_chosen)

        show_params(params)

        # A. Initialization
        # Initial guess for time iteration
        # initialize empty array
        exec("σ = np.zeros(({}))".format(params.str_nb_points))
        print("Shape array: {}".format(σ.shape))

        # Loop over values and indices
        # Order:  w, r, delta, p1, p2, ..., pn
        for (counter, (indices, vals)) in enumerate(zip(params.wrδ_ps_indices, params.wrδ_ps_grid)):
            #print(counter)
            #print(indices)
            #print(vals)
            w_value = vals[0]
            σ[indices] = 0.9*w_value

        # Interpolate
        σ_func =  eval('lambda x: interp({})'.format(params.str_c_grid_TI))
        σ_func(np.array(vals) + 1) 

        # B. Time Iteration Algo
        #-----------------------
        i = 0
        error = tol + 1

        while i < max_iter:
            σ_new = K_quadrature(σ, σ_func, params)
            error = np.max(np.abs(σ - σ_new))
            i += 1
            if verbose and i % print_skip == 0:
                print(f"Error at iteration {i} is {error}.")
            σ = σ_new

            #exec('σ_func = lambda x: interp({})'.format(params.str_c_grid_TI))
            σ_func = eval('lambda x: interp({})'.format(params.str_c_grid_TI))

            if (error < tol) or (i == max_iter):
                if (error < tol):
                    print("Convergence reached after {} iterations".format(i))
                if (i == max_iter):
                    raise Exception("Convergence NOT reached after {} iterations".format(i))
                params.c_grid_TI = σ
                params.c_function_TI = σ_func
                break

        end = time.time()
        elasped_time = end - start
        print("Elapsed Time: {}".format(elasped_time))
        
        # Measure accuracy
        # euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC(5000, 1000, params)
        euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian(nb_draws_gaussian, params)
        
        # Should take the mean of the absolute value
        median_E = np.median(np.abs(euler_bis))
        mean_E = np.mean(np.abs(euler_bis))
        print("Euler Bis TI")
        print("Mean: {}".format(mean_E))
        print("Median: {}".format(median_E))

        print("Accuracy (mean E)/Elapsed Time: {}".format(mean_E/elasped_time))
        list_elapsed_time_TI.append(elasped_time)
        list_median_euler_error.append(median_E)
        list_mean_euler_error.append(mean_E)
    print("Benchmark done. Creating df")
    df_TI = pd.DataFrame({"time": list_elapsed_time_TI,
                      "median_E": list_median_euler_error,
                      "mean_E": list_mean_euler_error,
                      "dim_p": list_dim_p})
    df_TI["mean_E_time"] = df_TI["mean_E"].div(df_TI["time"])
    df_TI["time_mean_E"] = df_TI["time"].div(df_TI["mean_E"])
    df_TI["dim_state"] = df_TI["dim_p"] + 3
    df_TI["label"] = "TI"

    # Save and load files
    if save_csv_file_TI == True:
        print("Saving TI benchmark do disk")
        df_TI.to_csv(output_folder + 'df_TI_dims.csv', index=False)
    
if load_csv_file_TI == True:
    print("Saving TI benchmark from disk")
    df_TI = pd.read_csv(output_folder + 'df_TI_dims.csv')
# Out:
# Benchmarking TI
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3)
# Error at iteration 10 is 0.006752349386817791.
#  17%|███████▌                                     | 1/6 [00:08<00:40,  8.01s/it]
# Convergence reached after 19 iterations
# Elapsed Time: 7.995707988739014
# Euler Bis TI
# Mean: 0.002655084438211535
# Median: 0.0007852078164263254
# Accuracy (mean E)/Elapsed Time: 0.00033206370742289485
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3, 3)
# Error at iteration 10 is 0.007400591996223227.
#  33%|███████████████                              | 2/6 [00:14<00:28,  7.04s/it]
# Convergence reached after 19 iterations
# Elapsed Time: 6.335501194000244
# Euler Bis TI
# Mean: 0.002903358378553839
# Median: 0.0008900460872553473
# Accuracy (mean E)/Elapsed Time: 0.0004582681448001834
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3, 3, 3)
# Error at iteration 10 is 0.008068625281705044.
#  50%|██████████████████████▌                      | 3/6 [00:39<00:45, 15.31s/it]
# Error at iteration 20 is 7.831673296276875e-05.
# Convergence reached after 20 iterations
# Elapsed Time: 25.134836435317993
# Euler Bis TI
# Mean: 0.0029643508530352875
# Median: 0.0009542865785536758
# Accuracy (mean E)/Elapsed Time: 0.00011793794086003903
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3, 3, 3, 3)
# Error at iteration 10 is 0.00876848755869064.
# Error at iteration 20 is 0.00010640151548058085.
#  67%|██████████████████████████████               | 4/6 [01:57<01:20, 40.09s/it]
# Convergence reached after 21 iterations
# Elapsed Time: 78.03371834754944
# Euler Bis TI
# Mean: 0.003332119220255099
# Median: 0.0010683627787249073
# Accuracy (mean E)/Elapsed Time: 4.2701018108792206e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3, 3, 3, 3, 3)
# Error at iteration 10 is 0.009506183432195892.
# Error at iteration 20 is 0.00014094901303396412.
#  83%|████████████████████████████████████▋       | 5/6 [06:13<01:57, 117.85s/it]
# Convergence reached after 21 iterations
# Elapsed Time: 255.66263508796692
# Euler Bis TI
# Mean: 0.0035009460406713834
# Median: 0.0011593645137425446
# Accuracy (mean E)/Elapsed Time: 1.3693616352920708e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 3
# grid_depth_chosen: 3
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Shape array: (10, 3, 3, 3, 3, 3, 3, 3, 3)
# Error at iteration 10 is 0.01028658226604029.
# Error at iteration 20 is 0.00018320846581265648.
# 100%|████████████████████████████████████████████| 6/6 [22:53<00:00, 228.91s/it]
# Convergence reached after 22 iterations
# Elapsed Time: 999.9835472106934
# Euler Bis TI
# Mean: 0.003671751158844097
# Median: 0.0012295789190454043
# Accuracy (mean E)/Elapsed Time: 3.6718115703862385e-06
# Benchmark done. Creating df
# Saving TI benchmark do disk
# Saving TI benchmark from disk

# %%
desired_time = 1
plt.plot(df_TI["dim_state"], df_TI["mean_E_time"]*desired_time)
plt.xlabel("dimension state")
plt.ylabel("(Euler error/Elapsed time (sec))*100")
# Out:
# Text(0, 0.5, '(Euler error/Elapsed time (sec))*100')

# %%
desired_accuracy = 0.003892
plt.plot(df_TI["dim_state"], df_TI["time_mean_E"]*desired_accuracy)
plt.xlabel("dimension state")
plt.ylabel("Elapsed time (sec)/Euler error")
#plt.yscale('log')
# Out:
# Text(0, 0.5, 'Elapsed time (sec)/Euler error')

# %%
n = len(df_TI["dim_state"])
data = df_TI["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range


p = plt.scatter(df_TI["time"], df_TI["mean_E"], c=list(df_TI["dim_state"].values), cmap=cmap, s=200, label="Time Iteration")
#plt.plot(df_TI["time"], df_TI["mean_E"])
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
#plt.xscale('log')
#plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))

figname = output_folder + 'Euler_error_time_TI_linear.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %%
n = len(df_TI["dim_state"])
data = df_TI["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range


p = plt.scatter(df_TI["time"], df_TI["mean_E"], c=list(df_TI["dim_state"].values), cmap=cmap, s=200, label="Time Iteration")
#plt.plot(df_TI["time"], df_TI["mean_E"])
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
#plt.xscale('log')
plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))

figname = output_folder + 'Euler_error_time_TI_log.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %% [markdown]
# ## I.B. Time iteration solution on sparse grid

# %%
# Remove tensor product grid

# Store parameters
class MyParams():
    """
    N: number of draws for innovation vector
    M: number of draws for the state vector
    lr: learning rate
    pre_train_model: whether or not pre-train the model before starting the full training loop (not used)
    nb_epochs: number of gradient descent steps during training
    bc: borrowing constraint 
    order_gauss: order for the Gaussian quadrature to use when solving with time iteration
    σ_shocks: parameter determining the variance of shocks
    use_Sobol: whether or not use Sobol sampling for the state stapce
    dim_p: number of different pi
    grid_depth: depth of the sparse grid
    nb_refinements: nb refinement for the adaptive sparse grid
    surplus_threshold: surplus threshold to use for the adaptive sparse grid
    name_params: name of params object initialized
    nb_points_w: nb grid points for w grid
    nb_points_other: nb grid points other dimensions
    w1: weight first element loss function
    w2: weight second element loss function
    debug: if True, print info on params when building it
    """
    def __init__(self, N, M, lr, pre_train_model, nb_epochs, 
                 bc, order_gauss, σ_shocks, use_Sobol, 
                 optimizer, dim_p,
                 grid_depth, nb_refinements, surplus_threshold,
                 name_params,
                 nb_points_w=10, nb_points_other=3, 
                 w1 = 0.5, w2 = 0.5,
                 debug=False):
        # savings-consumption with binding constraint
        # Model parameters
        self.β = 0.9 
        self.γ = 2.0
        self.one_min_γ = 1 - self.γ
        self.σ_shocks = σ_shocks #default 0.01
        self.σ_r = self.σ_shocks #0.01
        self.ρ_r = 0.9 #0.2
        self.σ_δ = self.σ_shocks
        self.ρ_δ = 0.9 #0.2
        self.σ_p = self.σ_shocks
        self.ρ_p = 0.9 
        self.rbar = 1.04
        # Level of borrowing constraint
        if isinstance(bc, (int, float)):
            self.bc = bc
            self.bc_torch = torch.tensor([self.bc])
        else:
            raise TypeError("bc_chosen must be a real number (int or float).")       
        # Standard deviations for ergodic distributions of exogenous state variables
        self.σ_e_r = self.σ_r/(1-self.ρ_r**2)**0.5
        self.σ_e_δ = self.σ_δ/(1-self.ρ_δ**2)**0.5
        self.σ_e_p = self.σ_p/(1-self.ρ_p**2)**0.5
        # grids
        self.dim_p = dim_p #(p1, p2, ..., pl)
        self.dim_state = 3 + dim_p #(w ,r, delta, p1, p2, ..., pl)
        self.dim_shock = 2 + dim_p #(e_r, e_delta, e_p1, e_p2, ..., e_pl)
        self.n_points_grid = nb_points_other #nb points for (r, δ, p1, ..., pl)
        self.n_points_w = nb_points_w #10 #nb points for w
        self.r_min = -2*self.σ_e_r 
        self.r_max = 2*self.σ_e_r 
        self.δ_min = -2*self.σ_e_δ
        self.δ_max = 2*self.σ_e_δ
        self.p_min = -2*self.σ_e_p
        self.p_max = 2*self.σ_e_p 
        # bounds for endogenous state variable (cash-in-hand)
        self.wmin = 0.001 #0.1 #4 stdev with bc =0, based on TI. 0.7752188662883139 - 1.3681603157252489
        self.wmax = 3.0 #4.0
        self.w_grid = np.linspace(self.wmin, self.wmax, self.n_points_w)
        self.r_grid = np.linspace(self.r_min, self.r_max, self.n_points_grid)
        self.δ_grid = np.linspace(self.δ_min, self.δ_max, self.n_points_grid)
        self.p_grid = np.linspace(self.p_min, self.p_max, self.n_points_grid)
        # Generate a grid for indices along each dimension
        self.indices_w = range(self.n_points_w)
        self.indices_r = range(self.n_points_grid)
        self.indices_δ = range(self.n_points_grid)
        self.indices_p = range(self.n_points_grid)
        # Functions
        self.u = lambda c: (1/self.one_min_γ)*(c**(self.one_min_γ) - 1)
        self.u_prime =  lambda c: c**(-self.γ)
        self.u_prime_inv =  lambda c: c**(-(1/self.γ))
        # Standard shocks
        σ_e = 0.5 #
        μ_e = 0.0 #location parameter shocks
        # Values passed as inputs
        self.N = N #number of draws inside expectation
        self.M = M #number of draws outside expecation
        self.MN = int(M*N)
        # To keep constant the number of function evaluations
        self.T = int((M*N)/2) #number of draws all in on expectation
        # To compare Loss functions
        #self.T = int((M*N)) #number of draws all in on expectation
        self.x_distribution = "Uniform" #"Normal" #Uniform or Normal
        self.σ_e = σ_e
        self.μ_e = μ_e
        self.e_distribution = "Lognormal" #"Normal"
        self.x_low = self.wmin
        self.x_high = self.wmax
        # Vectorized Monte Carlo requires the creation of some objects
        # To repeat vectors
        repeat_vector = torch.ones(N) #to repeat the same value n times using a matrix multiplication
        # To calculate the expectation wrt future shocks using a matrix multiplication
        A = sparse.eye(M) 
        B = sparse.csr_matrix(np.ones(N)/N)
        # Sparse kronecker product. Then convert to pytorch sparse
        # W used using the sum((sum)^2) formula
        W = sparse_mx_to_torch_sparse_tensor(sparse.kron(A, B))
        self.repeat_vector = repeat_vector
        self.W = W  
        # W used using the 2/N(N-1) sum() formula
        self.W_expanded = create_W_expanded_matrix(self.M, self.N)
        # Learning parameters
        self.lr = lr
        self.momentum = 0.9 #momentum for SGD with momentum
        self.lr_pre_train = 1e-3 #learning rate during pre-training
        self.optimizer = optimizer #"Adam" #default: #Adam or SGD or SWA
        self.freq_gamma = 0.95 #0.85
        self.use_scheduler = False #default: True
        self.pre_train_model = pre_train_model #default: True
        self.nb_epochs = nb_epochs
        self.nb_epochs_pre_train = int(self.nb_epochs/1)
        self.freq_scheduler = 1000 #int(self.nb_epochs/10)
        # Sobol sampling
        self.soboleng = torch.quasirandom.SobolEngine(dimension=1) #sobol draws for income
        self.use_Sobol = use_Sobol #Sobol for dimension M
        self.use_Sobol_T = use_Sobol #Sobol for all-in-one
        # DEBUG PARAMS
        self.error_correction=True #error correction for the model
        self.selective_error_correction=False #error correction for the model, only if give positive values
        self.abs_value=False
        self.perfect_forecast = False
        self.fake_bias=0.0
        # GAUSSIAN QUADRATURE
        # value e_r, e_δ, e_p1, e_p2, ..., e_pl
        strr = "chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ)"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "chaospy.Normal(0, self.σ_p)"
        if debug==True:
            print("Quadrature grid build for: {}".format(strr)) #debug
        self.distrib = eval('chaospy.J({})'.format(strr))
        #self.distrib = chaospy.J(chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ), chaospy.Normal(0, self.σ_p))
        self.order_gauss = order_gauss
        nodes, weights = dist(self.order_gauss, self.distrib, rule = "gaussian", sp=True)
        self.nodes = nodes
        self.weights = weights
        self.weights_torch = torch.tensor(weights)
        self.nodes_torch = torch.tensor(np.transpose(self.nodes)) #column=dim. Row=observation
        # Save the number of points for the guassian quadrature:
        self.N_gaussian = len(self.weights_torch)
        # Implied number of points for the current space (T=MN/2 <-> M = 2T/N)
        self.M_gaussian = int((2*self.T)/self.N_gaussian)
        self.MN_gaussian = self.N_gaussian*self.M_gaussian
        # Repeat nodes to match the number of function evaluations for the expectation
        self.nodes_torch_repeated = self.nodes_torch.repeat(self.M_gaussian, 1)
        # CREATE A W MATRIX FOR GAUSSIAN QUADRATURE:
        B_gaussian = sparse.csr_matrix(self.weights_torch)
        # Sparse kronecker product. Then convert to pytorch sparse
        A_gaussian = sparse.eye(self.M_gaussian) 
        self.W_gaussian = sparse_mx_to_torch_sparse_tensor(sparse.kron(A_gaussian, B_gaussian))
        # SCALE OF THE OBJECTIVE FUNCTION
        self.nb_points_test = 1000
        self.xvec_test_torch = torch.linspace(self.x_low, self.x_high, self.nb_points_test).unsqueeze(1) #add a dimension
        self.xvec_test = self.xvec_test_torch.numpy()
        self.swa_start = 1000
        self.swa_freq= 10
        # To measure accuracy during training
        self.M_accuracy = 5000
        self.N_accuracy = 100
        self.MN_accuracy = int(self.M_accuracy*self.N_accuracy)
        self.repeat_vector_accuracy = torch.ones(self.N_accuracy)
        # Sparse version        
        A = sparse.eye(self.M_accuracy)
        B = sparse.csr_matrix(np.ones(self.N_accuracy)/self.N_accuracy)
        # Sparse kronecker product. Then convert to pytorch sparse
        self.W_accuracy = sparse_mx_to_torch_sparse_tensor(sparse.kron(A, B))
        # randomly drawing current states
        self.r_accuracy = torch.normal(mean=0, std=self.σ_e_r, size=(self.M_accuracy,)) 
        self.δ_accuracy = torch.normal(mean=0, std=self.σ_e_δ, size=(self.M_accuracy,)) 
        # dimension (M, dim_p)
        self.p_accuracy = torch.normal(mean=0, std=self.σ_e_p, size=(self.M_accuracy, dim_p)) 
        #w = (params.wmin - params.wmax) * torch.rand(n) + params.wmax #uniform
        w = (self.wmin - self.wmax) * self.soboleng.draw(self.M_accuracy) + self.wmax #uniform
        self.w_accuracy = w.squeeze(1)
        # n_Monte_Carlo for each value today
        self.e_r_accuracy = torch.normal(mean=0, std=self.σ_r, size=(self.MN_accuracy,)) 
        self.e_δ_accuracy = torch.normal(mean=0, std=self.σ_δ, size=(self.MN_accuracy,)) 
        self.e_p_accuracy = torch.normal(mean=0, std=self.σ_p, size=(self.MN_accuracy, dim_p)) 
        #
        self.r_repeated_accuracy = torch.kron(self.r_accuracy, self.repeat_vector_accuracy)
        self.δ_repeated_accuracy = torch.kron(self.δ_accuracy, self.repeat_vector_accuracy)
        self.w_repeated_accuracy = torch.kron(self.w_accuracy, self.repeat_vector_accuracy)
        # dimension (MN, dim_p))
        self.p_repeated_accuracy = self.p_accuracy.repeat_interleave(self.N_accuracy, dim=0) #repeat N times
        # transitions of the exogenous processes
        #r = torch.normal(mean=0, std=σ_e_r, size=(n,)) 
        #torch.kron(r, repeat_vector).shape
        self.rnext_accuracy = self.r_repeated_accuracy*self.ρ_r + self.e_r_accuracy
        self.δnext_accuracy = self.δ_repeated_accuracy*self.ρ_δ + self.e_δ_accuracy
        self.pnext_accuracy = self.p_repeated_accuracy*self.ρ_p + self.e_p_accuracy
        # For the next period, the sum of p1, p2, ... , pl matter
        self.pnext_sum_accuracy = torch.sum(self.pnext_accuracy, axis=1) #sum over rows
        def identity_function(x):
            return x
        self.c_function_TI = identity_function #Initialization TI solution, interpolated
        self.ss = np.ones(self.dim_state) #steady-state value
        # Parameters for the adaptive sparse grid
        self.grid_depth = grid_depth # Initial depth of the sparse grid
        self.nb_refinements = nb_refinements # Nb of refinement steps for the sparse grid
        self.surplus_threshold = surplus_threshold #
        self.grid_dim = 3 + self.dim_p # Dimension input: (w, r, delta, vector ps)
        self.grid_out = 1 # Dimension output
        self.grid_order = 1 #1 # 1=linear, 2=quadratic, 3=cubic
        self.grid_rule = "localp" # Type of base functions
        # Need to set the domain
        ## 2 columns: min, max
        ## rows: corresponding to a variable
        ## Order: w, r, delta, p1, p2, ..., pn
        self.domain_transform = np.zeros((self.grid_dim, 2))
        self.domain_transform[0,:] = np.array([self.wmin, self.wmax])
        self.domain_transform[1,:] = np.array([self.r_min, self.r_max])
        self.domain_transform[2,:] = np.array([self.δ_min, self.δ_max])
        # max and min for the ps:
        self.domain_transform[3:,:] = np.array([self.p_min, self.p_max])
        # Store grid that is updating during time iteration
        self.grid_old = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth, self.grid_order, self.grid_rule)
        self.grid_old.setDomainTransform(self.domain_transform)
        self.grid_old_points = self.grid_old.getPoints() # Points of the grid
        # Let's store another grid to test for convergence of the time iteration algo
        self.grid_depth_test = 2
        self.grid_test = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth_test, self.grid_order, self.grid_rule)
        self.grid_test.setDomainTransform(self.domain_transform)
        self.grid_test_points = self.grid_old.getPoints()
        # To store sparse solution
        self.c_grid_TI_sparse = np.zeros((self.grid_old_points.shape[0],1))
        self.c_function_TI_sparse = identity_function # Initialization TI solution, using sparse grid
        # weights in the loss function
        self.w1 = w1
        self.w2 = w2
        # Check bad combination
        if (self.optimizer == "SWA") & (self.use_scheduler == True):
            raise('opt SWA and use_schedule = True')

# %%
# %%time
grid_depth_chosen = 2
dim_p_chosen = 2
name_params = "params_sparse"
debug = False #Fit TI solution dense grid

params_sparse = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                  nb_epochs_chosen, bc_chosen, order_gauss,
                  σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                  dim_p_chosen, grid_depth_chosen, nb_refinements_chosen, surplus_threshold_chosen,
                  name_params)

params_sparse.c_function_TI = params_TI.c_function_TI #Overwrite function using previous solution


# Initialization for sparse grid and TI
# initialize empty array
σ_sparse = np.zeros((params_sparse.grid_old_points.shape[0], params_sparse.grid_out))
print("Shape array: {}".format(σ_sparse.shape))

# Wage times 0.9
σ_sparse = 0.9*np.expand_dims(params_sparse.grid_old_points[:,0], 1)
    
# First interpolation
params_sparse.grid_old.loadNeededPoints(σ_sparse)

# Create function around interpolation object
def σ_sparse_interpolated(x):
    #return np.squeeze(params_sparse.grid_old.evaluateBatch(np.atleast_2d(x)), 1)
    return np.squeeze(params_sparse.grid_old.evaluateBatch(x), 1)

# Solve with a sparse grid
tol=0.0001
max_iter=100
verbose=True
print_skip = 1
i = 0
error = tol + 1

while i < max_iter:
    # If debug, fit TI solution
    if debug==True:
        σ_new_sparse = np.expand_dims(params_TI.c_function_TI(params_sparse.grid_old_points[:,:]), 1)
    else:
        # Update values based on past function
        σ_new_sparse = K_quadrature_sparse(σ_sparse, σ_sparse_interpolated, params_sparse, params_sparse.grid_old_points)
    # Here the grid is fixed
    # With adaptive sparse grid, test on other fixed grid
    error = np.max(np.abs(σ_sparse - σ_new_sparse))
    i += 1
    if verbose and i % print_skip == 0:
        print(f"Error at iteration {i} is {error}.")
    σ_sparse = copy.deepcopy(σ_new_sparse) # copy points
    
    # New interpolation object
    params_sparse.grid_old.loadNeededPoints(σ_sparse)
    
    if (error < tol) or (i == max_iter):
        if (error < tol):
            print("Convergence reached after {} iterations".format(i))
        if (i == max_iter):
            print("Convergence NOT reached after {} iterations".format(i))
        params_sparse.c_grid_TI_sparse = copy.deepcopy(σ_sparse) #value on grid
        params_sparse.c_function_TI_sparse = copy.deepcopy(σ_sparse_interpolated) #interpolation object (function)
        break
# Out:
# Shape array: (61, 1)
# Error at iteration 1 is 0.7711371721469218.
# Error at iteration 2 is 0.2643221162320517.
# Error at iteration 3 is 0.13100052179274124.
# Error at iteration 4 is 0.07665708129318127.
# Error at iteration 5 is 0.04902144488907667.
# Error at iteration 6 is 0.03297636219555522.
# Error at iteration 7 is 0.02286588213802032.
# Error at iteration 8 is 0.016146562340514592.
# Error at iteration 9 is 0.011521150880655417.
# Error at iteration 10 is 0.008263554729948552.
# Error at iteration 11 is 0.005936721657865185.
# Error at iteration 12 is 0.004261726000628574.
# Error at iteration 13 is 0.003052027735138907.
# Error at iteration 14 is 0.002178301741943889.
# Error at iteration 15 is 0.0015485440127593897.
# Error at iteration 16 is 0.001096196173272057.
# Error at iteration 17 is 0.0007726614782757046.
# Error at iteration 18 is 0.0005423341447567953.
# Error at iteration 19 is 0.0003791425843167051.
# Error at iteration 20 is 0.00026405932925110953.
# Error at iteration 21 is 0.00018326584143091296.
# Error at iteration 22 is 0.0001267839925378489.
# Error at iteration 23 is 8.745218015437928e-05.
# Convergence reached after 23 iterations
# CPU times: user 28.3 s, sys: 15.5 ms, total: 28.4 s
# Wall time: 2.55 s

# %%
# Number of dimensions (columns) in the data
data = params_sparse.grid_old.getPoints()
num_dims = data.shape[1]

# Create a figure with subplots for each additional dimension
fig, axs = plt.subplots(1, num_dims - 1, figsize=(15, 3))

# Create a scatter plot for the first dimension against each other dimension
for i in range(1, num_dims):
    axs[i - 1].scatter(data[:, 0], data[:, i])
    axs[i - 1].set_xlabel('Dimension 1')
    axs[i - 1].set_ylabel(f'Dimension {i+1}')
    axs[i - 1].set_title(f'Dim 1 vs Dim {i+1}')

plt.tight_layout()
plt.show()

# Create a figure with subplots for each additional dimension, this time for the second dimension
fig, axs = plt.subplots(1, num_dims - 1, figsize=(15, 3))

# Create a scatter plot for the second dimension against each other dimension
for i in range(num_dims):
    if i != 1:  # Skip the second dimension itself
        axs[i if i < 1 else i - 1].scatter(data[:, 1], data[:, i])  # Adjust index for skipped column
        axs[i if i < 1 else i - 1].set_xlabel('Dimension 2')
        axs[i if i < 1 else i - 1].set_ylabel(f'Dimension {i+1}')
        axs[i if i < 1 else i - 1].set_title(f'Dim 2 vs Dim {i+1}')

plt.tight_layout()
plt.show()

# Create a figure with 3D subplots for each additional dimension beyond the first two
fig = plt.figure(figsize=(15, 10))
subplot_index = 1

# Generate 3D scatter plots for dimensions 1 and 2 against each other dimension
for i in range(2, num_dims):
    ax = fig.add_subplot(1, num_dims - 2, subplot_index, projection='3d')
    ax.scatter(data[:, 0], data[:, 1], data[:, i])
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_zlabel(f'Dimension {i+1}')
    ax.set_title(f'Dim 1 & 2 vs Dim {i+1}')
    subplot_index += 1

plt.tight_layout()
plt.show()

# %%
# Plot the result
len_wec = params_sparse.nb_points_test

with torch.no_grad():
    rvec = np.zeros(len_wec)
    δvec = np.zeros(len_wec)
    wvec = params_sparse.xvec_test

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI_sparse = params_sparse.c_function_TI_sparse(state_next) #σ_func(state_next)
    k_next_TI_sparse = wvec.squeeze(1) - cvec_TI_sparse
    
plt.title("Multidimensional Consumption-Savings (decision rule) BEFORE TRAINING")
plt.plot(wvec, wvec, linestyle='--', color='black')
plt.plot(wvec, cvec_TI_sparse, label='c TI Sparse', color="blue", linestyle="dashed")
plt.plot(wvec, k_next_TI_sparse, label='kt+1 TI Sparse', color="green", linestyle="dashed")
w_grid_sparse = np.unique(params_sparse.grid_old.getPoints()[:,0])
plt.scatter(params_TI.w_grid, 0.05*np.ones(len(params_TI.w_grid)), label="grid points dense", alpha=0.5)
plt.scatter(w_grid_sparse, np.zeros(len(w_grid_sparse)), label="grid points sparse")
plt.xlabel("$w_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Sparse Grid")
plt.legend()
plt.show()


with torch.no_grad():
    rvec = np.linspace(params_sparse.r_min, params_sparse.r_max, len_wec)
    δvec = np.zeros(len_wec)
    wvec = np.ones(len_wec)

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI_sparse = params_sparse.c_function_TI_sparse(state_next) 

plt.plot(rvec, cvec_TI_sparse, label='c TI Sparse', color="blue", linestyle="dashdot")
#Order of the loop: w, r, delta, p1, p2, ..., pn
plt.scatter(params_TI.r_grid, 0.99*np.ones(len(params_TI.r_grid)), label="grid points dense", alpha=0.5)
r_grid_sparse = np.unique(params_sparse.grid_old.getPoints()[:,1])
plt.scatter(r_grid_sparse, np.ones(len(r_grid_sparse)), label="grid points sparse")
plt.xlabel("$r_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Sparse Grid")
plt.legend()
plt.show()

with torch.no_grad():
    rvec = np.zeros(len_wec)
    δvec = np.linspace(params_sparse.δ_min, params_sparse.δ_max, len_wec)
    wvec = np.ones(len_wec)

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI_sparse = params_sparse.c_function_TI_sparse(state_next) 

plt.plot(δvec, cvec_TI_sparse, label='c TI Sparse', color="blue", linestyle="dashdot")
#Order of the loop: w, r, delta, p1, p2, ..., pn
plt.scatter(params_TI.δ_grid, 0.99*np.ones(len(params_TI.δ_grid)), label="grid points dense", alpha=0.5)
δ_grid_sparse = np.unique(params_sparse.grid_old.getPoints()[:,1])
plt.scatter(δ_grid_sparse, np.ones(len(δ_grid_sparse)), label="grid points sparse")
plt.xlabel("$delta_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Sparse Grid")
plt.legend()

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC_sparse(1000, 1000, params_sparse)

print("Euler TI Sparse")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI Sparse")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./50)
plt.scatter(w, euler_bis, alpha=0.1)
w_grid_sparse = np.unique(params_sparse.grid_old.getPoints()[:,0])
plt.scatter(w_grid_sparse, np.zeros(len(w_grid_sparse)), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
plt.title("Euler Error Adaptive Sparse Grid (Monte-Carlo)")
# Out:
# Euler TI Sparse
# Mean: 0.04197742716308163
# Median: 0.017785031427218934
# Min: 1.8917117338701495e-05
# Max: 0.7905510398093655
# std dev.: 0.06131735679309268
#
# Euler Bis TI Sparse
# Mean: 0.02325962638733118
# Median: 0.008949645730092548
# Min: 9.45869286805845e-06
# Max: 1.1850475668552316
# std dev.: 0.04777798180416955
# Text(0.5, 1.0, 'Euler Error Adaptive Sparse Grid (Monte-Carlo)')

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian_sparse(2000, params_sparse, debug=False)

print("Euler TI")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./50)
plt.scatter(w, euler_bis, alpha=0.1)
plt.scatter(w_grid_sparse, np.zeros(len(w_grid_sparse)), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
plt.title("Euler Error Sparse Grid (Gaussian quadrature)")
# Out:
# Euler TI
# Mean: 0.04262521516908747
# Median: 0.017492245745732826
# Min: 1.4344520878006861e-05
# Max: 1.382913548777613
# std dev.: 0.07036607964296786
#
# Euler Bis TI
# Mean: 0.02329538743727533
# Median: 0.008797929263150928
# Min: 7.17233760183511e-06
# Max: 1.6478073283908066
# std dev.: 0.049043142483440424
# Text(0.5, 1.0, 'Euler Error Sparse Grid (Gaussian quadrature)')

# %% [markdown]
# ## Modify dimension of state and innovation vectors

# %%
#list_dim_p = list(range(1, 10)) #DEBUG
list_dim_p = list(range(1, 15)) #Version for the paper.
list_elapsed_time_TI = []
list_median_euler_error = []
list_mean_euler_error = []

# TI parameters
tol=0.0001
max_iter=100
verbose=True
print_skip = 10
name_params = "params_sparse"
grid_depth_chosen = 2

### Important options for the code
# Run benchmark. Can be time-consuming
if benchmark_TI_sparse == True:
    print("Benchmarking TI sparse grid")
    for dim_p in tqdm(list_dim_p):
        start = time.time()

        params_sparse = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                          nb_epochs_chosen, bc_chosen, order_gauss,
                          σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                          dim_p, grid_depth_chosen, 
                          nb_refinements_chosen, surplus_threshold_chosen,
                          name_params)

        params_sparse.c_function_TI = params_TI.c_function_TI #Overwrite function using previous solution

        # Initialization for sparse grid and TI
        # initialize empty array
        σ_sparse = np.zeros((params_sparse.grid_old_points.shape[0], params_sparse.grid_out))
        print("Shape array: {}".format(σ_sparse.shape))

        # Wage times 0.9
        σ_sparse = 0.9*np.expand_dims(params_sparse.grid_old_points[:,0], 1)

        # First interpolation
        params_sparse.grid_old.loadNeededPoints(σ_sparse)

        # Create function around interpolation object
        def σ_sparse_interpolated(x):
            #return np.squeeze(params_sparse.grid_old.evaluateBatch(np.atleast_2d(x)), 1)
            return np.squeeze(params_sparse.grid_old.evaluateBatch(x), 1)

        # Solve with a sparse grid
        tol=0.0001
        max_iter=100
        i = 0
        error = tol + 1

        while i < max_iter:
            σ_new_sparse = K_quadrature_sparse(σ_sparse, σ_sparse_interpolated, params_sparse, params_sparse.grid_old_points)
            # Here the grid is fixed
            # With adaptive sparse grid, test on other fixed grid
            error = np.max(np.abs(σ_sparse - σ_new_sparse))
            i += 1
            if verbose and i % print_skip == 0:
                print(f"Error at iteration {i} is {error}.")
            σ_sparse = copy.deepcopy(σ_new_sparse) # copy points

            # New interpolation object
            params_sparse.grid_old.loadNeededPoints(σ_sparse)

            if (error < tol) or (i == max_iter):
                if (error < tol):
                    print("Convergence reached after {} iterations".format(i))
                if (i == max_iter):
                    raise Exception("Convergence NOT reached after {} iterations".format(i))
                params_sparse.c_grid_TI_sparse = copy.deepcopy(σ_sparse) #value on grid
                params_sparse.c_function_TI_sparse = copy.deepcopy(σ_sparse_interpolated) #interpolation object (function)
                break

        end = time.time()
        elasped_time = end - start
        print("Elapsed Time: {}".format(elasped_time))
        
        # Measure accuracy using sparse grid
        # euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC_sparse(1000, 1000, params_sparse)
        euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian_sparse(nb_draws_gaussian, params_sparse)
        
        # Should take the mean of the absolute value
        median_E = np.median(np.abs(euler_bis))
        mean_E = np.mean(np.abs(euler_bis))
        print("Euler Bis TI")
        print("Mean: {}".format(mean_E))
        print("Median: {}".format(median_E))

        print("Accuracy (mean E)/Elapsed Time: {}".format(mean_E/elasped_time))
        list_elapsed_time_TI.append(elasped_time)
        list_median_euler_error.append(median_E)
        list_mean_euler_error.append(mean_E)

    print("Creating dataframe benchmark sparse grid")
    df_TI_sparse = pd.DataFrame({"time": list_elapsed_time_TI,
                          "median_E": list_median_euler_error,
                          "mean_E": list_mean_euler_error,
                          "dim_p": list_dim_p})
    df_TI_sparse["mean_E_time"] = df_TI_sparse["mean_E"].div(df_TI_sparse["time"])
    df_TI_sparse["time_mean_E"] = df_TI_sparse["time"].div(df_TI_sparse["mean_E"])
    df_TI_sparse["dim_state"] = df_TI_sparse["dim_p"] + 3
    df_TI_sparse["label"] = "TI Sparse"
    df_TI_sparse

# Save and load files
if save_csv_file_TI_sparse == True:
    print("Saving TI sparse benchmark do disk")
    df_TI_sparse.to_csv(output_folder + 'df_TI_sparse_dims.csv', index=False)
    
if load_csv_file_TI_sparse == True:
    print("Saving TI sparse benchmark from disk")
    df_TI_sparse = pd.read_csv(output_folder + 'df_TI_sparse_dims.csv')
# Out:
# Benchmarking TI sparse grid
#   0%|                                                    | 0/14 [00:00<?, ?it/s]
# Shape array: (41, 1)
# Error at iteration 10 is 0.008252569502393614.
#   7%|███▏                                        | 1/14 [00:01<00:16,  1.29s/it]
# Error at iteration 20 is 0.0002619856324823644.
# Convergence reached after 23 iterations
# Elapsed Time: 1.2773995399475098
# Euler Bis TI
# Mean: 0.021811301301418173
# Median: 0.008270132772478234
# Accuracy (mean E)/Elapsed Time: 0.017074768401994594
# Shape array: (61, 1)
# Error at iteration 10 is 0.008263554729948552.
# Error at iteration 20 is 0.00026405932925110953.
#  14%|██████▎                                     | 2/14 [00:03<00:20,  1.68s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 1.933180570602417
# Euler Bis TI
# Mean: 0.023282914909994828
# Median: 0.008958092662789408
# Accuracy (mean E)/Elapsed Time: 0.012043838668800304
# Shape array: (85, 1)
# Error at iteration 10 is 0.00827453245345633.
# Error at iteration 20 is 0.0002661448195404592.
#  21%|█████████▍                                  | 3/14 [00:06<00:26,  2.40s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 3.2345168590545654
# Euler Bis TI
# Mean: 0.028626667170530275
# Median: 0.009339300160274677
# Accuracy (mean E)/Elapsed Time: 0.00885036882413954
# Shape array: (113, 1)
# Error at iteration 10 is 0.008285502713378579.
# Error at iteration 20 is 0.0002682421250415068.
#  29%|████████████▌                               | 4/14 [00:10<00:30,  3.09s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 4.1091954708099365
# Euler Bis TI
# Mean: 0.02862348263733236
# Median: 0.010081973772612662
# Accuracy (mean E)/Elapsed Time: 0.006965714539661598
# Shape array: (145, 1)
# Error at iteration 10 is 0.008296465548497611.
# Error at iteration 20 is 0.0002703512671542452.
#  36%|███████████████▋                            | 5/14 [00:16<00:37,  4.16s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 5.99484920501709
# Euler Bis TI
# Mean: 0.02601981067779983
# Median: 0.009993361527398936
# Accuracy (mean E)/Elapsed Time: 0.004340361164718513
# Shape array: (181, 1)
# Error at iteration 10 is 0.008307420997367254.
# Error at iteration 20 is 0.00027247226695759075.
#  43%|██████████████████▊                         | 6/14 [00:25<00:44,  5.58s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 8.263853311538696
# Euler Bis TI
# Mean: 0.028905015941157002
# Median: 0.010005241402600895
# Accuracy (mean E)/Elapsed Time: 0.0034977648866053026
# Shape array: (221, 1)
# Error at iteration 10 is 0.008318369098287537.
# Error at iteration 20 is 0.0002746051450621678.
#  50%|██████████████████████                      | 7/14 [00:36<00:52,  7.55s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 11.464218378067017
# Euler Bis TI
# Mean: 0.040942946838636
# Median: 0.010519084299400072
# Accuracy (mean E)/Elapsed Time: 0.003571368364455336
# Shape array: (265, 1)
# Error at iteration 10 is 0.008329309888909897.
# Error at iteration 20 is 0.00027674992182835645.
#  57%|█████████████████████████▏                  | 8/14 [00:52<01:00, 10.07s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 15.310113906860352
# Euler Bis TI
# Mean: 0.029721948276638318
# Median: 0.011842203435825316
# Accuracy (mean E)/Elapsed Time: 0.0019413277038598732
# Shape array: (313, 1)
# Error at iteration 10 is 0.008340243406184777.
# Error at iteration 20 is 0.00027890661723062316.
#  64%|████████████████████████████▎               | 9/14 [01:12<01:06, 13.25s/it]
# Convergence reached after 23 iterations
# Elapsed Time: 20.06812357902527
# Euler Bis TI
# Mean: 0.031070242668054027
# Median: 0.011239236799291952
# Accuracy (mean E)/Elapsed Time: 0.0015482385558223248
# Shape array: (365, 1)
# Error at iteration 10 is 0.008351169686831472.
# Error at iteration 20 is 0.0002810752508757286.
# Convergence reached after 23 iterations
# Elapsed Time: 28.003491401672363
#  71%|██████████████████████████████▋            | 10/14 [01:40<01:11, 17.88s/it]
# Euler Bis TI
# Mean: 0.03303916351821213
# Median: 0.01123123792972891
# Accuracy (mean E)/Elapsed Time: 0.0011798230100779161
# Shape array: (421, 1)
# Error at iteration 10 is 0.008362088766998177.
# Error at iteration 20 is 0.0002832558419934017.
# Convergence reached after 23 iterations
# Elapsed Time: 37.30408835411072
#  79%|█████████████████████████████████▊         | 11/14 [02:18<01:11, 23.92s/it]
# Euler Bis TI
# Mean: 0.030541001471328273
# Median: 0.011529088060381998
# Accuracy (mean E)/Elapsed Time: 0.0008187038691688819
# Shape array: (481, 1)
# Error at iteration 10 is 0.008373000682217802.
# Error at iteration 20 is 0.0002854484094720888.
# Convergence reached after 23 iterations
# Elapsed Time: 49.87977600097656
#  86%|████████████████████████████████████▊      | 12/14 [03:08<01:03, 31.95s/it]
# Euler Bis TI
# Mean: 0.03177893216260828
# Median: 0.012084299464149406
# Accuracy (mean E)/Elapsed Time: 0.0006371105628458736
# Shape array: (545, 1)
# Error at iteration 10 is 0.008383905467710395.
# Error at iteration 20 is 0.00028765297184008.
# Convergence reached after 23 iterations
# Elapsed Time: 62.48906445503235
#  93%|███████████████████████████████████████▉   | 13/14 [04:11<00:41, 41.37s/it]
# Euler Bis TI
# Mean: 0.03959222733654831
# Median: 0.011515744981715592
# Accuracy (mean E)/Elapsed Time: 0.0006335864952025199
# Shape array: (613, 1)
# Error at iteration 10 is 0.008394803158068509.
# Error at iteration 20 is 0.0002898695471875712.
# Convergence reached after 23 iterations
# Elapsed Time: 82.87774205207825
# 100%|███████████████████████████████████████████| 14/14 [05:35<00:00, 23.93s/it]
# Euler Bis TI
# Mean: 0.04417351772290324
# Median: 0.011698575094693964
# Accuracy (mean E)/Elapsed Time: 0.0005329961534804572
# Creating dataframe benchmark sparse grid
# Saving TI sparse benchmark do disk
# Saving TI sparse benchmark from disk

# %%
desired_time = 1
plt.plot(df_TI["dim_state"], df_TI["mean_E_time"]*desired_time, label="TI")
plt.plot(df_TI_sparse["dim_state"], df_TI_sparse["mean_E_time"]*desired_time, label="TI Sparse")
plt.xlabel("dimension state")
plt.ylabel("(Euler error/Elapsed time (sec))*100")
plt.legend()

# %%
desired_accuracy = 0.003892
plt.plot(df_TI["dim_state"], df_TI["time_mean_E"]*desired_accuracy, label="TI")
plt.plot(df_TI_sparse["dim_state"], df_TI_sparse["time_mean_E"]*desired_accuracy, label="TI Sparse")
plt.xlabel("dimension state")
plt.ylabel("Elapsed time (sec)/Euler error")
plt.yscale('log')
plt.legend()

# %%
n = len(df_TI_sparse["dim_state"])
data = df_TI_sparse["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range

p = plt.scatter(df_TI_sparse["time"], df_TI_sparse["mean_E"], c=list(df_TI_sparse["dim_state"].values), cmap=cmap, s=200, label="Time Iteration Sparse")
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
#plt.xscale('log')
#plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))

figname = output_folder + 'Euler_error_time_TI_linear_sparse.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %% [markdown]
# ---
# ---
#
# # Adaptive Sparse Grid and Time Iteration
#
# Refine selectively the sparse grid

# %%
# %%time

## Combination that works: 
## DEFAULT: 2, 2, 1e-3 works
# 1, 3, 1e-3 works
# 3, 5, 1e-3 works
grid_depth_chosen = 2 #3 #depth of the initial sparse grid 
nb_refinements_chosen = 2 #3 #5
surplus_threshold_chosen = 1e-3 #control which points are added or not
plot_iteration = True #plot successive iterations
name_params = "params_asparse"

params_asparse = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                  nb_epochs_chosen, bc_chosen, order_gauss,
                  σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                  dim_p_chosen, grid_depth_chosen, nb_refinements_chosen, surplus_threshold_chosen,
                  name_params)

 
params_asparse.c_function_TI = params_TI.c_function_TI #Overwrite function using previous solution

# Initialization for sparse grid and TI
# initialize empty array
σ_asparse = np.zeros((params_asparse.grid_old_points.shape[0], params_asparse.grid_out))
print("Shape array: {}".format(σ_asparse.shape))

# Wage times 0.9
σ_asparse = 0.9*np.expand_dims(params_asparse.grid_old_points[:,0], 1)
    
# First interpolation
params_asparse.grid_old.loadNeededPoints(σ_asparse)

# Create function around interpolation object
def σ_asparse_interpolated(x):
    #return np.squeeze(params_sparse.grid_old.evaluateBatch(np.atleast_2d(x)), 1)
    return np.squeeze(params_asparse.grid_old.evaluateBatch(x), 1)

# Test points:
σ_old_test = σ_asparse_interpolated(params_asparse.grid_test_points)
    
# Create a grid that is copied at each iteration, before being refined
grid_to_copy = Tasmanian.makeLocalPolynomialGrid(params_asparse.grid_dim, params_asparse.grid_out, 
                                                 params_asparse.grid_depth, params_asparse.grid_order, 
                                                 params_asparse.grid_rule)

grid_to_copy.setDomainTransform(params_asparse.domain_transform)
    
# Solve with a sparse grid
tol= 0.0001
max_iter=100
verbose=True
print_skip = 1
i = 0
error = tol + 1
show_every = 1
verbosity = 1 #To display more info on the sparse grid

colors_cvec = cm.Blues(10*np.linspace(0, 1, max_iter))
colors_knext = cm.Greens(10*np.linspace(0, 1, max_iter))
    
if plot_iteration == True:
    # Initialize plot outside the loop
    plt.figure()
    plt.xlabel("$w_t$")
    plt.ylabel("$c_t$")
    plt.title("Time Iteration Adaptive Sparse Grid")
    
# I. Loop for value function iteration
convergence_reached = 0
while (convergence_reached == 0) and (i < max_iter):
    i+=1
    
    # Create a fresh grid
    #grid_new = Tasmanian.makeLocalPolynomialGrid(params.grid_dim, params.grid_out, params.grid_depth, params.grid_order, params.grid_rule)
    #grid_new.setDomainTransform(params.domain_transform)
    grid_new = Tasmanian.copyGrid(grid_to_copy)

    # Keep track of the number of points on grid as we refine it
    num_points = [] 
    # II. Loop over refinement:
    i_refinement = 0
    while ((grid_new.getNumNeeded() > 0) and (i_refinement<=params_asparse.nb_refinements-1)):
        
        grid_new_points = grid_new.getNeededPoints()
        num_points_to_add = grid_new.getNumNeeded() 
        num_points.append(grid_new_points)
        if verbosity==1:
            print("Refinement: {}. Needed points: {}".format(i_refinement, grid_new.getNumNeeded()))
        i_refinement+=1
        
        # Update values based on past function
        σ_asparse_new = K_quadrature_sparse(σ_asparse, σ_asparse_interpolated, params_asparse, grid_new_points)
        
        # Load function values into the grid structure
        grid_new.loadNeededPoints(σ_asparse_new)
        
        # Refine
        # Other options: "stable", "fds"
        grid_new.setSurplusRefinement(params_asparse.surplus_threshold, -1, "classic")
        # grid_new.setSurplusRefinement(params_asparse.surplus_threshold, -1, "fds")
        
    # Update the grid
    # print("updating grid")
    params_asparse.grid_old = Tasmanian.copyGrid(grid_new)

    # Test new interpolation on a fixed grid
    σ_new_test = σ_asparse_interpolated(params_asparse.grid_test_points)
    diff = np.max(np.abs(σ_new_test - σ_old_test))

    if i % show_every == 0:
        print(f"Iter {i} Diff : {diff}")

    if diff < tol:
        print(f"Iter {i} Convergence reached")
        convergence_reached = 1
        params_asparse.c_grid_TI_sparse = σ_new_test #value on grid
        params_asparse.c_function_TI_sparse = σ_asparse_interpolated #interpolation object (function)
        params_asparse.grid_old_points = params_asparse.grid_old.getPoints() #Update grid points
    if (i == max_iter):
        print("Convergence NOT reached after {} iterations".format(i))
        
    #Update
    σ_old_test = σ_new_test.copy()   
    
    if plot_iteration == True:
        # Plot the result
        len_wec = params_asparse.nb_points_test

        with torch.no_grad():
            rvec = np.zeros(len_wec)
            δvec = np.zeros(len_wec)
            wvec = params_asparse.xvec_test

            wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
            state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
            cvec_TI_asparse = σ_asparse_interpolated(state_next) #σ_func(state_next)
            k_next_TI_asparse = wvec.squeeze(1) - cvec_TI_asparse

        plt.plot(wvec, wvec, linestyle='--', color='black')
        if i==1:
            plt.plot(wvec, cvec_TI_asparse, label=f"c TI A-Sparse", color=colors_cvec[i], linestyle="dashdot")
            plt.plot(wvec, k_next_TI_asparse, label=f"kt+1 TI A-Sparse", color=colors_knext[i], linestyle="dashdot")
        else:
            plt.plot(wvec, cvec_TI_asparse, color=colors_cvec[i], linestyle="dashdot")
            plt.plot(wvec, k_next_TI_asparse, color=colors_knext[i], linestyle="dashdot")
        

plt.legend()
plt.show()
        
# Save grid object ot disk
params_asparse.grid_old.write(output_folder + "a-sparse_grid")
# Out:
# Shape array: (61, 1)
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 56
# Iter 1 Diff : 0.7711371721469218
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 78
# Iter 2 Diff : 0.264322213142701
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 102
# Iter 3 Diff : 0.13149740659585873
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 108
# Iter 4 Diff : 0.07602482924657816
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 107
# Iter 5 Diff : 0.04744665237939327
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 107
# Iter 6 Diff : 0.030934548863212008
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 116
# Iter 7 Diff : 0.019964380760503886
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 124
# Iter 8 Diff : 0.013200693055310575
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 122
# Iter 9 Diff : 0.00902028613767314
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 10 Diff : 0.006054439515930543
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 11 Diff : 0.0036998189840546925
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 12 Diff : 0.0023235882730243684
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 13 Diff : 0.0014390139340734187
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 14 Diff : 0.0008860482460966157
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 15 Diff : 0.0005425217696979345
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 16 Diff : 0.00033169950882938615
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 17 Diff : 0.00020234702540000704
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 18 Diff : 0.00012349006614331692
# Refinement: 0. Needed points: 61
# Refinement: 1. Needed points: 120
# Iter 19 Diff : 7.533629571665479e-05
# Iter 19 Convergence reached
# CPU times: user 56.4 s, sys: 152 ms, total: 56.6 s
# Wall time: 5.25 s

# %%
# Plot the result
len_wec = params_asparse.nb_points_test

with torch.no_grad():
    rvec = np.zeros(len_wec) 
    δvec = np.zeros(len_wec)
    wvec = params_asparse.xvec_test

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI_asparse = params_asparse.c_function_TI_sparse(state_next) #σ_func(state_next)
    k_next_TI_asparse = wvec.squeeze(1) - cvec_TI_asparse

plt.plot(wvec, wvec, linestyle='--', color='black')
plt.plot(wvec, cvec_TI_asparse, label='c TI A-Sparse', color="blue", linestyle="dashdot")
plt.plot(wvec, k_next_TI_asparse, label='kt+1 TI A-Sparse', color="green", linestyle="dashdot")
w_grid_sparse = np.unique(params_asparse.grid_old.getPoints()[:,0])
plt.scatter(w_grid_sparse, np.zeros(len(w_grid_sparse)), label="grid points")
plt.xlabel("$w_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Adaptive Sparse Grid")
plt.legend()
plt.show()

cvec_TI_asparse_copy = copy.deepcopy(cvec_TI_asparse)

# Plot the result
len_wec = params_asparse.nb_points_test

with torch.no_grad():
    rvec = np.linspace(params_asparse.r_min, params_asparse.r_max, len_wec)
    δvec = np.zeros(len_wec)
    wvec = np.ones(len_wec)

    wrδ_next = np.column_stack((wvec, rvec, δvec)) #w, r, delta
    state_next = np.hstack((wrδ_next, np.zeros((len_wec, dim_p_chosen)))) 
    cvec_TI_asparse = params_asparse.c_function_TI_sparse(state_next)
    k_next_TI_asparse = wvec - cvec_TI_asparse

plt.plot(rvec, cvec_TI_asparse, label='c TI A-Sparse', color="blue", linestyle="dashdot")
r_grid_sparse = np.unique(params_asparse.grid_old.getPoints()[:,1])
plt.scatter(r_grid_sparse, np.ones(len(r_grid_sparse)), label="grid points")
plt.xlabel("$r_t$")
plt.ylabel("$c_t$")
plt.title("Solution Time Iteration Adaptive Sparse Grid")
plt.legend()

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC_sparse(1000, 1000, params_asparse)

print("Euler TI A-Sparse")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI A-Sparse")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./50)
plt.scatter(w, euler_bis, alpha=0.1)
w_grid_asparse = np.unique(params_asparse.grid_old.getPoints()[:,0])
plt.scatter(w_grid_asparse, np.zeros(len(w_grid_sparse)), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
plt.title("Euler Error Adaptive Sparse Grid (Monte-Carlo)")
# Out:
# Euler TI A-Sparse
# Mean: 0.01238051560285933
# Median: 0.0031615805173290656
# Min: 1.1917048694520815e-06
# Max: 0.2247828608938075
# std dev.: 0.023002426195149975
#
# Euler Bis TI A-Sparse
# Mean: 0.006454111747732616
# Median: 0.001583838344193178
# Min: 5.958519021520559e-07
# Max: 0.1357645706671946
# std dev.: 0.012447616058363859
# Text(0.5, 1.0, 'Euler Error Adaptive Sparse Grid (Monte-Carlo)')

# %%
# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian_sparse(2000, params_asparse, debug=False)

print("Euler TI A-Sparse")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("\nEuler Bis TI A-Sparse")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./50)
plt.scatter(w, euler_bis, alpha=0.1)
plt.scatter(w_grid_asparse, np.zeros(len(w_grid_sparse)), label="grid points")
plt.plot(smoothed[:,0], smoothed[:,1])
plt.title("Euler Error Sparse Grid (Gaussian quadrature)")
# Out:
# Euler TI A-Sparse
# Mean: 0.01308192806272863
# Median: 0.003179239574657877
# Min: 1.6657179269241595e-06
# Max: 0.1187883059195659
# std dev.: 0.02358636288002142
#
# Euler Bis TI A-Sparse
# Mean: 0.006819477328957452
# Median: 0.0015886133622031728
# Min: 8.328600038520761e-07
# Max: 0.06527043526746978
# std dev.: 0.012615922051478318
# Text(0.5, 1.0, 'Euler Error Sparse Grid (Gaussian quadrature)')

# %% [markdown]
# ## Illustrate the sparse grid

# %%
# Number of dimensions (columns) in the data
data = params_asparse.grid_old.getPoints()
num_dims = data.shape[1]

# Create a figure with subplots for each additional dimension
fig, axs = plt.subplots(1, num_dims - 1, figsize=(15, 3))

# Create a scatter plot for the first dimension against each other dimension
for i in range(1, num_dims):
    axs[i - 1].scatter(data[:, 0], data[:, i])
    axs[i - 1].set_xlabel('Dimension 1')
    axs[i - 1].set_ylabel(f'Dimension {i+1}')
    axs[i - 1].set_title(f'Dim 1 vs Dim {i+1}')

plt.tight_layout()
plt.show()

# Create a figure with subplots for each additional dimension, this time for the second dimension
fig, axs = plt.subplots(1, num_dims - 1, figsize=(15, 3))

# Create a scatter plot for the second dimension against each other dimension
for i in range(num_dims):
    if i != 1:  # Skip the second dimension itself
        axs[i if i < 1 else i - 1].scatter(data[:, 1], data[:, i])  # Adjust index for skipped column
        axs[i if i < 1 else i - 1].set_xlabel('Dimension 2')
        axs[i if i < 1 else i - 1].set_ylabel(f'Dimension {i+1}')
        axs[i if i < 1 else i - 1].set_title(f'Dim 2 vs Dim {i+1}')

plt.tight_layout()
plt.show()


# Create a figure with 3D subplots for each additional dimension beyond the first two
fig = plt.figure(figsize=(15, 10))
subplot_index = 1

# Generate 3D scatter plots for dimensions 1 and 2 against each other dimension
for i in range(2, num_dims):
    ax = fig.add_subplot(1, num_dims - 2, subplot_index, projection='3d')
    ax.scatter(data[:, 0], data[:, 1], data[:, i])
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    ax.set_zlabel(f'Dimension {i+1}')
    ax.set_title(f'Dim 1 & 2 vs Dim {i+1}')
    subplot_index += 1

plt.tight_layout()
plt.show()

# %%
points = params_asparse.grid_old.getPoints()
print(points.shape)
plt.hist(points[:,0], bins=30, density=True)

vals = params_asparse.c_function_TI_sparse(points)

fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(1,1,1, projection='3d')
ax.scatter(points[:,0], points[:,1], vals, marker='x',color='red',alpha=0.5)
ax.set_ylabel("r")
ax.set_xlabel("w")
ax.view_init(20, 110)
# Out:
# (181, 5)

# %%
## Order:  w, r, delta, p1, p2, ..., pn
fig = plt.figure(figsize=(16,8))
# First subplot
ax = fig.add_subplot(3,2,1)
ax.scatter(points[:,0],points[:,1],marker='x',color='red',alpha=0.5)
ax.set_ylabel("r")
ax.set_xlabel("w")

# Second subplot
ax = fig.add_subplot(3,2,2, projection='3d')
ax.scatter(points[:,0], points[:,1], vals, marker='x',color='red',alpha=0.5)
ax.set_ylabel("r")
ax.set_xlabel("w")
ax.view_init(20, 110)

ax = fig.add_subplot(3,2,3)
ax.scatter(points[:,0],points[:,2],marker='x',color='red',alpha=0.5)
ax.set_ylabel("delta")
ax.set_xlabel("w")

# Second subplot
ax = fig.add_subplot(3,2,4, projection='3d')
ax.scatter(points[:,0], points[:,2], vals, marker='x',color='red',alpha=0.5)
ax.set_title("w-delta")
ax.view_init(20, 110)

ax = fig.add_subplot(3,2,5)
ax.scatter(points[:,0],points[:,2],marker='x',color='red',alpha=0.5)
ax.set_ylabel("p1")
ax.set_xlabel("w")

# Second subplot
ax = fig.add_subplot(3,2,6, projection='3d')
ax.scatter(points[:,0], points[:,2], vals, marker='x',color='red',alpha=0.5)
ax.set_title("w-p1")
ax.view_init(20, 110)

# %% [markdown]
# ### Modify dimension state and innovation vectors

# %%
#list_dim_p = list(range(1, 10)) #Test
list_dim_p = list(range(1, 15)) #Paper

list_elapsed_time_TI = []
list_median_euler_error = []
list_mean_euler_error = []

# TI parameters
tol=0.0001
max_iter= 100
verbosity = 0
print_skip = 1
show_every = print_skip

grid_depth_chosen = 2 #3 #depth of the initial sparse grid 
nb_refinements_chosen = 2 #3 
surplus_threshold_chosen = 1e-2 #control which points are added or not
name_params = "params_asparse"

if benchmark_TI_sparse == True:
    print("Benchmarking TI sparse grid")
    for dim_p in tqdm(list_dim_p):
        start = time.time()

        params_asparse = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen, 
                          nb_epochs_chosen, bc_chosen, order_gauss,
                          σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen, 
                          dim_p, grid_depth_chosen, nb_refinements_chosen, surplus_threshold_chosen,
                          name_params)


        params_asparse.c_function_TI = params_TI.c_function_TI #Overwrite function using previous solution

        # Initialization for sparse grid and TI
        # initialize empty array
        σ_asparse = np.zeros((params_asparse.grid_old_points.shape[0], params_asparse.grid_out))
        print("Shape array: {}".format(σ_asparse.shape))

        # Wage times 0.9
        σ_asparse = 0.9*np.expand_dims(params_asparse.grid_old_points[:,0], 1)

        # First interpolation
        params_asparse.grid_old.loadNeededPoints(σ_asparse)

        # Create function around interpolation object
        def σ_asparse_interpolated(x):
            #return np.squeeze(params_sparse.grid_old.evaluateBatch(np.atleast_2d(x)), 1)
            return np.squeeze(params_asparse.grid_old.evaluateBatch(x), 1)

        # Test points:
        σ_old_test = σ_asparse_interpolated(params_asparse.grid_test_points)

        # Create a grid that is copied at each iteration, before being refined
        grid_to_copy = Tasmanian.makeLocalPolynomialGrid(params_asparse.grid_dim, params_asparse.grid_out, 
                                                         params_asparse.grid_depth, params_asparse.grid_order, 
                                                         params_asparse.grid_rule)

        grid_to_copy.setDomainTransform(params_asparse.domain_transform)

        # Solve with a sparse grid
        i = 0
        error = tol + 1
        # I. Loop for value function iteration
        convergence_reached = 0
        while (convergence_reached == 0) and (i < max_iter):
            i+=1

            # Create a fresh grid
            #grid_new = Tasmanian.makeLocalPolynomialGrid(params.grid_dim, params.grid_out, params.grid_depth, params.grid_order, params.grid_rule)
            #grid_new.setDomainTransform(params.domain_transform)
            grid_new = Tasmanian.copyGrid(grid_to_copy)

            # Keep track of the number of points on grid as we refine it
            num_points = [] 
            # II. Loop over refinement:
            i_refinement = 0
            while ((grid_new.getNumNeeded() > 0) and (i_refinement<=params_asparse.nb_refinements-1)):

                grid_new_points = grid_new.getNeededPoints()
                num_points_to_add = grid_new.getNumNeeded() 
                num_points.append(grid_new_points)
                if verbosity==1:
                    print("Refinement: {}. Needed points: {}".format(i_refinement, grid_new.getNumNeeded()))
                i_refinement+=1

                # Update values based on past function
                σ_asparse_new = K_quadrature_sparse(σ_asparse, σ_asparse_interpolated, params_asparse, grid_new_points)

                # Load function values into the grid structure
                grid_new.loadNeededPoints(σ_asparse_new)

                # Refine
                # Other options: "stable", "fds"
                grid_new.setSurplusRefinement(params_asparse.surplus_threshold, -1, "classic")
                # grid_new.setSurplusRefinement(params_asparse.surplus_threshold, -1, "fds")

            # Update the grid
            # print("updating grid")
            params_asparse.grid_old = Tasmanian.copyGrid(grid_new)

            # Test new interpolation on a fixed grid
            σ_new_test = σ_asparse_interpolated(params_asparse.grid_test_points)
            diff = np.max(np.abs(σ_new_test - σ_old_test))

            if i % show_every == 0:
                print(f"Iter {i} Diff : {diff}. Grid points: {len(grid_new.getPoints())}")

            if diff < tol:
                print(f"Iter {i} Convergence reached")
                convergence_reached = 1
                params_asparse.c_grid_TI_sparse = σ_new_test #value on grid
                params_asparse.c_function_TI_sparse = σ_asparse_interpolated #interpolation object (function)
                params_asparse.grid_old_points = params_asparse.grid_old.getPoints() #Update grid points
            if (i == max_iter):
                raise Exception("Convergence NOT reached after {} iterations".format(i))

            #Update
            σ_old_test = σ_new_test.copy()   

        end = time.time()
        elasped_time = end - start
        print("Elapsed Time: {}".format(elasped_time))
        
        # Measure accuracy using sparse grid
        #euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_MC_sparse(1000, 1000, params_asparse)
        euler, euler_bis, c, c_RHS, w = evaluate_accuracy_TI_Gaussian_sparse(nb_draws_gaussian, params_asparse)
        
        # Should take the mean of the absolute value
        median_E = np.median(np.abs(euler_bis))
        mean_E = np.mean(np.abs(euler_bis))
        print("Euler Bis TI")
        print("Mean: {}".format(mean_E))
        print("Median: {}".format(median_E))

        print("Accuracy (mean E)/Elapsed Time: {}".format(mean_E/elasped_time))
        list_elapsed_time_TI.append(elasped_time)
        list_median_euler_error.append(median_E)
        list_mean_euler_error.append(mean_E)
    print("Creating df asparse")
    df_TI_a_sparse = pd.DataFrame({"time": list_elapsed_time_TI,
                      "median_E": list_median_euler_error,
                      "mean_E": list_mean_euler_error,
                      "dim_p": list_dim_p})
    df_TI_a_sparse["mean_E_time"] = df_TI_a_sparse["mean_E"].div(df_TI_a_sparse["time"])
    df_TI_a_sparse["time_mean_E"] = df_TI_a_sparse["time"].div(df_TI_a_sparse["mean_E"])
    df_TI_a_sparse["dim_state"] = df_TI_a_sparse["dim_p"] + 3
    df_TI_a_sparse["label"] = "TI Adaptive Sparse"
    df_TI_a_sparse

# Save and load files
if save_csv_file_TI_sparse == True:
    print("Saving TI a-sparse benchmark do disk")
    df_TI_a_sparse.to_csv(output_folder + 'df_TI_a_sparse_dims.csv', index=False)
    
if load_csv_file_TI_sparse == True:
    print("Saving TI a-sparse benchmark from disk")
    df_TI_a_sparse = pd.read_csv(output_folder + 'df_TI_a_sparse_dims.csv')
# Out:
# Benchmarking TI sparse grid
#   0%|                                                    | 0/14 [00:00<?, ?it/s]
# Shape array: (41, 1)
# Iter 1 Diff : 0.7711283650466707. Grid points: 54
# Iter 2 Diff : 0.2643158454193679. Grid points: 59
# Iter 3 Diff : 0.13133911560699407. Grid points: 65
# Iter 4 Diff : 0.07580556688921525. Grid points: 65
# Iter 5 Diff : 0.04729519996585152. Grid points: 65
# Iter 6 Diff : 0.03080251394485045. Grid points: 65
# Iter 7 Diff : 0.020529623254143203. Grid points: 65
# Iter 8 Diff : 0.013835718627805527. Grid points: 65
# Iter 9 Diff : 0.009359700858507125. Grid points: 65
# Iter 10 Diff : 0.0063277613123475795. Grid points: 65
# Iter 11 Diff : 0.004264761085112978. Grid points: 65
# Iter 12 Diff : 0.00286208415173439. Grid points: 71
# Iter 13 Diff : 0.0019118858037823205. Grid points: 71
# Iter 14 Diff : 0.0012065789070709876. Grid points: 71
# Iter 15 Diff : 0.0007438085435973463. Grid points: 77
# Iter 16 Diff : 0.001168844891705989. Grid points: 77
# Iter 17 Diff : 0.0010023403597554381. Grid points: 77
# Iter 18 Diff : 0.0007525196109912091. Grid points: 77
# Iter 19 Diff : 0.0005359402281563952. Grid points: 77
# Iter 20 Diff : 0.00037142646487131614. Grid points: 77
# Iter 21 Diff : 0.00025309971369535944. Grid points: 77
# Iter 22 Diff : 0.00017042022745794583. Grid points: 77
#   7%|███▏                                        | 1/14 [00:01<00:23,  1.80s/it]
# Iter 23 Diff : 0.00011369182156273361. Grid points: 77
# Iter 24 Diff : 7.527192375422764e-05. Grid points: 77
# Iter 24 Convergence reached
# Elapsed Time: 1.7901220321655273
# Euler Bis TI
# Mean: 0.006990816136813359
# Median: 0.00254744785715455
# Accuracy (mean E)/Elapsed Time: 0.0039052176394681333
# Shape array: (61, 1)
# Iter 1 Diff : 0.7711371721469218. Grid points: 84
# Iter 2 Diff : 0.2643221162320517. Grid points: 95
# Iter 3 Diff : 0.13134847678931894. Grid points: 101
# Iter 4 Diff : 0.07580124230705443. Grid points: 101
# Iter 5 Diff : 0.047279618449645344. Grid points: 101
# Iter 6 Diff : 0.0307806307401699. Grid points: 101
# Iter 7 Diff : 0.020506041130752273. Grid points: 101
# Iter 8 Diff : 0.013813763517613431. Grid points: 101
# Iter 9 Diff : 0.009341251224695979. Grid points: 101
# Iter 10 Diff : 0.006313485941888297. Grid points: 101
# Iter 11 Diff : 0.004254505190365299. Grid points: 101
# Iter 12 Diff : 0.002855242608156283. Grid points: 109
# Iter 13 Diff : 0.0019076900057384272. Grid points: 109
# Iter 14 Diff : 0.001203836713131956. Grid points: 109
# Iter 15 Diff : 0.0007421256010911037. Grid points: 117
# Iter 16 Diff : 0.001174070264089666. Grid points: 117
# Iter 17 Diff : 0.0010081050613206521. Grid points: 117
# Iter 18 Diff : 0.0007573267840257358. Grid points: 117
# Iter 19 Diff : 0.0005396238829602495. Grid points: 117
# Iter 20 Diff : 0.0003741539514043879. Grid points: 117
# Iter 21 Diff : 0.00025508804167673205. Grid points: 117
# Iter 22 Diff : 0.0001718595678112944. Grid points: 117
# Iter 23 Diff : 0.00011473093265079726. Grid points: 117
#  14%|██████▎                                     | 2/14 [00:04<00:29,  2.45s/it]
# Iter 24 Diff : 7.60216797548452e-05. Grid points: 117
# Iter 24 Convergence reached
# Elapsed Time: 2.8837318420410156
# Euler Bis TI
# Mean: 0.007524807975334994
# Median: 0.0028004941936073946
# Accuracy (mean E)/Elapsed Time: 0.0026093993434594697
# Shape array: (85, 1)
# Iter 1 Diff : 0.7711459787316726. Grid points: 121
# Iter 2 Diff : 0.26432838494464295. Grid points: 139
# Iter 3 Diff : 0.13135773485250923. Grid points: 145
# Iter 4 Diff : 0.07579636748167151. Grid points: 145
# Iter 5 Diff : 0.047263799078925084. Grid points: 145
# Iter 6 Diff : 0.030758760501927496. Grid points: 145
# Iter 7 Diff : 0.020482630767688637. Grid points: 145
# Iter 8 Diff : 0.013792068378550626. Grid points: 145
# Iter 9 Diff : 0.009323096508103701. Grid points: 145
# Iter 10 Diff : 0.006299501978658917. Grid points: 145
# Iter 11 Diff : 0.004244512481393681. Grid points: 145
# Iter 12 Diff : 0.0028486233005227124. Grid points: 155
# Iter 13 Diff : 0.0019036720129748108. Grid points: 155
# Iter 14 Diff : 0.0012012329486512652. Grid points: 155
# Iter 15 Diff : 0.0007405451374833394. Grid points: 165
# Iter 16 Diff : 0.0011793214535715801. Grid points: 165
# Iter 17 Diff : 0.0010138815721114636. Grid points: 165
# Iter 18 Diff : 0.0007621428825710375. Grid points: 165
# Iter 19 Diff : 0.0005433152831377797. Grid points: 165
# Iter 20 Diff : 0.0003768882360370984. Grid points: 165
# Iter 21 Diff : 0.0002570823053793525. Grid points: 165
# Iter 22 Diff : 0.00017330406455307035. Grid points: 165
# Iter 23 Diff : 0.00011577449491295688. Grid points: 165
#  21%|█████████▍                                  | 3/14 [00:09<00:36,  3.30s/it]
# Iter 24 Diff : 7.677524346716424e-05. Grid points: 165
# Iter 24 Convergence reached
# Elapsed Time: 4.272497177124023
# Euler Bis TI
# Mean: 0.0074358848787854075
# Median: 0.0028683155468050003
# Accuracy (mean E)/Elapsed Time: 0.0017404072069605854
# Shape array: (113, 1)
# Iter 1 Diff : 0.7711547848009848. Grid points: 165
# Iter 2 Diff : 0.2643346515638483. Grid points: 191
# Iter 3 Diff : 0.13136688985155254. Grid points: 197
# Iter 4 Diff : 0.07579093773703005. Grid points: 197
# Iter 5 Diff : 0.04724773981846542. Grid points: 197
# Iter 6 Diff : 0.030736903062828835. Grid points: 197
# Iter 7 Diff : 0.02045939236624661. Grid points: 197
# Iter 8 Diff : 0.01377063279163937. Grid points: 197
# Iter 9 Diff : 0.009305235332557116. Grid points: 197
# Iter 10 Diff : 0.0062858072154958755. Grid points: 197
# Iter 11 Diff : 0.0042347802659312705. Grid points: 197
# Iter 12 Diff : 0.002842223428859869. Grid points: 209
# Iter 13 Diff : 0.001899829218470428. Grid points: 209
# Iter 14 Diff : 0.0011987653506593254. Grid points: 209
# Iter 15 Diff : 0.0007390653475591868. Grid points: 221
# Iter 16 Diff : 0.0011845978677333946. Grid points: 221
# Iter 17 Diff : 0.0010196695272506329. Grid points: 221
# Iter 18 Diff : 0.0007669676338695197. Grid points: 221
# Iter 19 Diff : 0.0005470142358661167. Grid points: 221
# Iter 20 Diff : 0.00037962919691247876. Grid points: 221
# Iter 21 Diff : 0.0002590824385126922. Grid points: 221
# Iter 22 Diff : 0.00017475369020281128. Grid points: 221
# Iter 23 Diff : 0.00011682250531697136. Grid points: 221
#  29%|████████████▌                               | 4/14 [00:15<00:46,  4.63s/it]
# Iter 24 Diff : 7.753262555110219e-05. Grid points: 221
# Iter 24 Convergence reached
# Elapsed Time: 6.611388444900513
# Euler Bis TI
# Mean: 0.007851610292793644
# Median: 0.0029281372014045015
# Accuracy (mean E)/Elapsed Time: 0.001187588712753633
# Shape array: (145, 1)
# Iter 1 Diff : 0.7711635903549243. Grid points: 216
# Iter 2 Diff : 0.2643409160963637. Grid points: 251
# Iter 3 Diff : 0.1313759418409377. Grid points: 257
# Iter 4 Diff : 0.07578494827938109. Grid points: 257
# Iter 5 Diff : 0.04723143861119694. Grid points: 257
# Iter 6 Diff : 0.030715058275061935. Grid points: 257
# Iter 7 Diff : 0.02043632616137403. Grid points: 257
# Iter 8 Diff : 0.013749456376125346. Grid points: 257
# Iter 9 Diff : 0.009287666365249692. Grid points: 257
# Iter 10 Diff : 0.006272399495192316. Grid points: 257
# Iter 11 Diff : 0.004225305907240351. Grid points: 271
# Iter 12 Diff : 0.00283604025094375. Grid points: 271
# Iter 13 Diff : 0.0018295357045590155. Grid points: 271
# Iter 14 Diff : 0.0011619867099044168. Grid points: 285
# Iter 15 Diff : 0.0014748702684839188. Grid points: 285
# Iter 16 Diff : 0.0012153157410657034. Grid points: 285
# Iter 17 Diff : 0.000897467707543731. Grid points: 285
# Iter 18 Diff : 0.0006334898064901395. Grid points: 285
# Iter 19 Diff : 0.0004366693734201288. Grid points: 285
# Iter 20 Diff : 0.0002965784992934317. Grid points: 285
# Iter 21 Diff : 0.00019933864368137932. Grid points: 285
# Iter 22 Diff : 0.0001329111758681112. Grid points: 285
#  36%|███████████████▋                            | 5/14 [00:25<00:57,  6.43s/it]
# Iter 23 Diff : 8.804692733876962e-05. Grid points: 285
# Iter 23 Convergence reached
# Elapsed Time: 9.538128852844238
# Euler Bis TI
# Mean: 0.007795247047188464
# Median: 0.003020193424427664
# Accuracy (mean E)/Elapsed Time: 0.0008172721471322908
# Shape array: (181, 1)
# Iter 1 Diff : 0.7711723953935561. Grid points: 274
# Iter 2 Diff : 0.26434717854887335. Grid points: 319
# Iter 3 Diff : 0.1313848908746491. Grid points: 325
# Iter 4 Diff : 0.07577839419717591. Grid points: 325
# Iter 5 Diff : 0.04721489337873619. Grid points: 325
# Iter 6 Diff : 0.030693226012430852. Grid points: 325
# Iter 7 Diff : 0.0204134324217895. Grid points: 325
# Iter 8 Diff : 0.013728538789202771. Grid points: 325
# Iter 9 Diff : 0.009270388316205969. Grid points: 325
# Iter 10 Diff : 0.006259276709661421. Grid points: 325
# Iter 11 Diff : 0.00421608682303809. Grid points: 341
# Iter 12 Diff : 0.0028300710809863183. Grid points: 341
# Iter 13 Diff : 0.0018256067471031923. Grid points: 341
# Iter 14 Diff : 0.0011595943583901924. Grid points: 357
# Iter 15 Diff : 0.0014795216085006224. Grid points: 357
# Iter 16 Diff : 0.0012207527661871609. Grid points: 357
# Iter 17 Diff : 0.000902141912445309. Grid points: 357
# Iter 18 Diff : 0.0006371657783499352. Grid points: 357
# Iter 19 Diff : 0.00043945895989727646. Grid points: 357
# Iter 20 Diff : 0.00029866073844342367. Grid points: 357
# Iter 21 Diff : 0.00020088013763697177. Grid points: 357
# Iter 22 Diff : 0.00013404742457301388. Grid points: 357
#  43%|██████████████████▊                         | 6/14 [00:39<01:12,  9.08s/it]
# Iter 23 Diff : 8.888235482151785e-05. Grid points: 357
# Iter 23 Convergence reached
# Elapsed Time: 14.101798295974731
# Euler Bis TI
# Mean: 0.008063838179081404
# Median: 0.003079045116178847
# Accuracy (mean E)/Elapsed Time: 0.0005718304864269102
# Shape array: (221, 1)
# Iter 1 Diff : 0.7711811999169444. Grid points: 339
# Iter 2 Diff : 0.26435343892803176. Grid points: 395
# Iter 3 Diff : 0.13139373700619172. Grid points: 401
# Iter 4 Diff : 0.07577127046097565. Grid points: 401
# Iter 5 Diff : 0.04719810202254249. Grid points: 401
# Iter 6 Diff : 0.030671406169936244. Grid points: 401
# Iter 7 Diff : 0.020390711450054333. Grid points: 401
# Iter 8 Diff : 0.013707879725991967. Grid points: 401
# Iter 9 Diff : 0.009253399937973361. Grid points: 401
# Iter 10 Diff : 0.006246436799339339. Grid points: 401
# Iter 11 Diff : 0.00420712048457661. Grid points: 419
# Iter 12 Diff : 0.0028243132885574784. Grid points: 419
# Iter 13 Diff : 0.001821847932929277. Grid points: 419
# Iter 14 Diff : 0.00115733184617417. Grid points: 437
# Iter 15 Diff : 0.0014842233201739496. Grid points: 437
# Iter 16 Diff : 0.001226220365832864. Grid points: 437
# Iter 17 Diff : 0.0009068386179609256. Grid points: 437
# Iter 18 Diff : 0.0006408590327136032. Grid points: 437
# Iter 19 Diff : 0.0004422619118003013. Grid points: 437
# Iter 20 Diff : 0.00030075337101687083. Grid points: 437
# Iter 21 Diff : 0.00020242978620776952. Grid points: 437
# Iter 22 Diff : 0.00013519013408558322. Grid points: 437
#  50%|██████████████████████                      | 7/14 [00:57<01:23, 11.94s/it]
# Iter 23 Diff : 8.972294070708209e-05. Grid points: 437
# Iter 23 Convergence reached
# Elapsed Time: 17.63760495185852
# Euler Bis TI
# Mean: 0.007927980577917269
# Median: 0.003096545709045939
# Accuracy (mean E)/Elapsed Time: 0.0004494930348852086
# Shape array: (265, 1)
# Iter 1 Diff : 0.771190003925152. Grid points: 411
# Iter 2 Diff : 0.26435969724050334. Grid points: 479
# Iter 3 Diff : 0.13140248028854717. Grid points: 485
# Iter 4 Diff : 0.07576357192332073. Grid points: 485
# Iter 5 Diff : 0.04718106242231368. Grid points: 485
# Iter 6 Diff : 0.03064959866519712. Grid points: 485
# Iter 7 Diff : 0.02036816358321314. Grid points: 485
# Iter 8 Diff : 0.013687478919683693. Grid points: 485
# Iter 9 Diff : 0.009236700025443856. Grid points: 485
# Iter 10 Diff : 0.006233877752683581. Grid points: 485
# Iter 11 Diff : 0.004198404415844514. Grid points: 505
# Iter 12 Diff : 0.002818764297570109. Grid points: 505
# Iter 13 Diff : 0.0018182568369253804. Grid points: 505
# Iter 14 Diff : 0.0011551971047258913. Grid points: 525
# Iter 15 Diff : 0.001488974473118132. Grid points: 525
# Iter 16 Diff : 0.0012317178682448304. Grid points: 525
# Iter 17 Diff : 0.0009115572998141808. Grid points: 525
# Iter 18 Diff : 0.0006445691827730027. Grid points: 525
# Iter 19 Diff : 0.00044507796464698934. Grid points: 525
# Iter 20 Diff : 0.0003028562303568627. Grid points: 525
# Iter 21 Diff : 0.00020398749412042783. Grid points: 525
# Iter 22 Diff : 0.0001363392573827671. Grid points: 525
# Iter 23 Diff : 9.056866838830224e-05. Grid points: 525
# Iter 23 Convergence reached
# Elapsed Time: 24.343526601791382
#  57%|█████████████████████████▏                  | 8/14 [01:21<01:35, 15.98s/it]
# Euler Bis TI
# Mean: 0.008247054005787983
# Median: 0.0033960434355262414
# Accuracy (mean E)/Elapsed Time: 0.00033877811299456924
# Shape array: (313, 1)
# Iter 1 Diff : 0.7711988074182463. Grid points: 490
# Iter 2 Diff : 0.26436595349293635. Grid points: 571
# Iter 3 Diff : 0.13141112077421813. Grid points: 577
# Iter 4 Diff : 0.07575529331862652. Grid points: 577
# Iter 5 Diff : 0.04716377243969294. Grid points: 577
# Iter 6 Diff : 0.030627803437856205. Grid points: 577
# Iter 7 Diff : 0.0203457891923855. Grid points: 577
# Iter 8 Diff : 0.013667336141146125. Grid points: 577
# Iter 9 Diff : 0.009220287415292905. Grid points: 577
# Iter 10 Diff : 0.006221597605291285. Grid points: 577
# Iter 11 Diff : 0.0041899361924842005. Grid points: 599
# Iter 12 Diff : 0.002813421585067255. Grid points: 599
# Iter 13 Diff : 0.001814831085369617. Grid points: 599
# Iter 14 Diff : 0.0011531881113020503. Grid points: 621
# Iter 15 Diff : 0.0014937741607472521. Grid points: 621
# Iter 16 Diff : 0.001237244619549438. Grid points: 621
# Iter 17 Diff : 0.0009162974473702068. Grid points: 621
# Iter 18 Diff : 0.0006482958510745096. Grid points: 621
# Iter 19 Diff : 0.00044790685973850053. Grid points: 621
# Iter 20 Diff : 0.0003049691526380016. Grid points: 621
# Iter 21 Diff : 0.00020555316694004233. Grid points: 621
# Iter 22 Diff : 0.00013749474707758225. Grid points: 621
# Iter 23 Diff : 9.141952017310828e-05. Grid points: 621
# Iter 23 Convergence reached
# Elapsed Time: 34.89694309234619
#  64%|████████████████████████████▎               | 9/14 [01:57<01:49, 21.98s/it]
# Euler Bis TI
# Mean: 0.008206632449551006
# Median: 0.003429191459672243
# Accuracy (mean E)/Elapsed Time: 0.00023516766003928104
# Shape array: (365, 1)
# Iter 1 Diff : 0.7712076103962866. Grid points: 576
# Iter 2 Diff : 0.2643722076919519. Grid points: 671
# Iter 3 Diff : 0.13141965851523207. Grid points: 677
# Iter 4 Diff : 0.07574642926310227. Grid points: 677
# Iter 5 Diff : 0.04714622991689721. Grid points: 677
# Iter 6 Diff : 0.03060602045049099. Grid points: 677
# Iter 7 Diff : 0.02032358868323647. Grid points: 677
# Iter 8 Diff : 0.013647451198950389. Grid points: 677
# Iter 9 Diff : 0.009204160985758936. Grid points: 677
# Iter 10 Diff : 0.006209594439510857. Grid points: 677
# Iter 11 Diff : 0.004181713441080648. Grid points: 701
# Iter 12 Diff : 0.0028082826802302563. Grid points: 701
# Iter 13 Diff : 0.0018115683547623718. Grid points: 701
# Iter 14 Diff : 0.0011513028878671339. Grid points: 725
# Iter 15 Diff : 0.0014986214996484115. Grid points: 725
# Iter 16 Diff : 0.0012427999830664227. Grid points: 725
# Iter 17 Diff : 0.0009210585630423651. Grid points: 725
# Iter 18 Diff : 0.000652038669373356. Grid points: 725
# Iter 19 Diff : 0.00045074834402525354. Grid points: 725
# Iter 20 Diff : 0.0003070919770213898. Grid points: 725
# Iter 21 Diff : 0.00020712671122913306. Grid points: 725
# Iter 22 Diff : 0.0001386565554730712. Grid points: 725
# Iter 23 Diff : 9.227547735712882e-05. Grid points: 725
# Iter 23 Convergence reached
# Elapsed Time: 46.59377121925354
#  71%|██████████████████████████████▋            | 10/14 [02:44<01:58, 29.70s/it]
# Euler Bis TI
# Mean: 0.008212304017200514
# Median: 0.003519796939293829
# Accuracy (mean E)/Elapsed Time: 0.00017625325880054574
# Shape array: (421, 1)
# Iter 1 Diff : 0.771216412859342. Grid points: 669
# Iter 2 Diff : 0.2643784598441783. Grid points: 779
# Iter 3 Diff : 0.13142809356308827. Grid points: 785
# Iter 4 Diff : 0.07573697425454062. Grid points: 785
# Iter 5 Diff : 0.04712843267782585. Grid points: 785
# Iter 6 Diff : 0.030584249689055154. Grid points: 785
# Iter 7 Diff : 0.020301562496287895. Grid points: 785
# Iter 8 Diff : 0.013627823939968975. Grid points: 785
# Iter 9 Diff : 0.00918831965646838. Grid points: 785
# Iter 10 Diff : 0.006197866383659045. Grid points: 785
# Iter 11 Diff : 0.004173733838112703. Grid points: 811
# Iter 12 Diff : 0.0028033451632532014. Grid points: 811
# Iter 13 Diff : 0.0018084663707402804. Grid points: 811
# Iter 14 Diff : 0.0011495394999780917. Grid points: 837
# Iter 15 Diff : 0.0015035156288427665. Grid points: 837
# Iter 16 Diff : 0.0012483833387162413. Grid points: 837
# Iter 17 Diff : 0.0009258401619258727. Grid points: 837
# Iter 18 Diff : 0.0006557972782545995. Grid points: 837
# Iter 19 Diff : 0.0004536021699150794. Grid points: 837
# Iter 20 Diff : 0.00030922454538950817. Grid points: 837
# Iter 21 Diff : 0.00020870803436578989. Grid points: 837
# Iter 22 Diff : 0.00013982463454276228. Grid points: 837
# Iter 23 Diff : 9.313652034581565e-05. Grid points: 837
# Iter 23 Convergence reached
# Elapsed Time: 64.51330375671387
#  79%|█████████████████████████████████▊         | 11/14 [03:49<02:01, 40.53s/it]
# Euler Bis TI
# Mean: 0.0084509819027839
# Median: 0.0036663924851562113
# Accuracy (mean E)/Elapsed Time: 0.0001309959560380507
# Shape array: (481, 1)
# Iter 1 Diff : 0.7712252148074747. Grid points: 769
# Iter 2 Diff : 0.26438470995619334. Grid points: 895
# Iter 3 Diff : 0.13143642596882033. Grid points: 901
# Iter 4 Diff : 0.07572692267231695. Grid points: 901
# Iter 5 Diff : 0.04711037852858513. Grid points: 901
# Iter 6 Diff : 0.030562491163418803. Grid points: 901
# Iter 7 Diff : 0.020279711107004328. Grid points: 901
# Iter 8 Diff : 0.013608454246976764. Grid points: 901
# Iter 9 Diff : 0.009172762387291922. Grid points: 901
# Iter 10 Diff : 0.006186411611436515. Grid points: 901
# Iter 11 Diff : 0.004165995109431941. Grid points: 929
# Iter 12 Diff : 0.0027986066646699115. Grid points: 929
# Iter 13 Diff : 0.00180552290725422. Grid points: 929
# Iter 14 Diff : 0.001147896056183484. Grid points: 957
# Iter 15 Diff : 0.0015084557093576478. Grid points: 957
# Iter 16 Diff : 0.0012539940827933638. Grid points: 957
# Iter 17 Diff : 0.0009306417714780579. Grid points: 957
# Iter 18 Diff : 0.000659571326929953. Grid points: 957
# Iter 19 Diff : 0.00045646809515442754. Grid points: 957
# Iter 20 Diff : 0.0003113667024101652. Grid points: 957
# Iter 21 Diff : 0.0002102970447264152. Grid points: 957
# Iter 22 Diff : 0.00014099893616204007. Grid points: 957
# Iter 23 Diff : 9.400262866376963e-05. Grid points: 957
# Iter 23 Convergence reached
# Elapsed Time: 85.98768353462219
#  86%|████████████████████████████████████▊      | 12/14 [05:15<01:49, 54.56s/it]
# Euler Bis TI
# Mean: 0.008416203802564243
# Median: 0.00367613583472004
# Accuracy (mean E)/Elapsed Time: 9.787685231891997e-05
# Shape array: (545, 1)
# Iter 1 Diff : 0.7712340162407494. Grid points: 876
# Iter 2 Diff : 0.26439095803461976. Grid points: 1019
# Iter 3 Diff : 0.13144465578295073. Grid points: 1025
# Iter 4 Diff : 0.07571626877716864. Grid points: 1025
# Iter 5 Diff : 0.04709206525822829. Grid points: 1025
# Iter 6 Diff : 0.030540744907145978. Grid points: 1025
# Iter 7 Diff : 0.020258035025116694. Grid points: 1025
# Iter 8 Diff : 0.013589342044598496. Grid points: 1025
# Iter 9 Diff : 0.009157488180410844. Grid points: 1025
# Iter 10 Diff : 0.006175228341590788. Grid points: 1025
# Iter 11 Diff : 0.004158495028686593. Grid points: 1055
# Iter 12 Diff : 0.0027940648633204557. Grid points: 1055
# Iter 13 Diff : 0.001802735784695697. Grid points: 1085
# Iter 14 Diff : 0.0019327876305412772. Grid points: 1085
# Iter 15 Diff : 0.0015265888500259894. Grid points: 1085
# Iter 16 Diff : 0.0011041998989864688. Grid points: 1085
# Iter 17 Diff : 0.0007696884472339072. Grid points: 1085
# Iter 18 Diff : 0.0005263992873791867. Grid points: 1085
# Iter 19 Diff : 0.00035593991210491893. Grid points: 1085
# Iter 20 Diff : 0.00023885089469666276. Grid points: 1085
# Iter 21 Diff : 0.00015939227895400698. Grid points: 1085
# Iter 22 Diff : 0.00010591633727385918. Grid points: 1085
# Iter 23 Diff : 7.014717360998013e-05. Grid points: 1085
# Iter 23 Convergence reached
# Elapsed Time: 119.93947553634644
#  93%|███████████████████████████████████████▉   | 13/14 [07:16<01:14, 74.62s/it]
# Euler Bis TI
# Mean: 0.00857090991274941
# Median: 0.0037271732640854482
# Accuracy (mean E)/Elapsed Time: 7.146029173816158e-05
# Shape array: (613, 1)
# Iter 1 Diff : 0.7712428171592312. Grid points: 990
# Iter 2 Diff : 0.26439720408601786. Grid points: 1151
# Iter 3 Diff : 0.13145278305549946. Grid points: 1157
# Iter 4 Diff : 0.07570500671087865. Grid points: 1157
# Iter 5 Diff : 0.0470734906393413. Grid points: 1157
# Iter 6 Diff : 0.030519010978968586. Grid points: 1157
# Iter 7 Diff : 0.020236534796740147. Grid points: 1157
# Iter 8 Diff : 0.013570487289163324. Grid points: 1157
# Iter 9 Diff : 0.009142496075779993. Grid points: 1157
# Iter 10 Diff : 0.006164314836865303. Grid points: 1157
# Iter 11 Diff : 0.004151231417727663. Grid points: 1189
# Iter 12 Diff : 0.0027897174872262287. Grid points: 1189
# Iter 13 Diff : 0.0018001028702772093. Grid points: 1221
# Iter 14 Diff : 0.001936924265680151. Grid points: 1221
# Iter 15 Diff : 0.0015316789145387588. Grid points: 1221
# Iter 16 Diff : 0.0011087258197808314. Grid points: 1221
# Iter 17 Diff : 0.0007733610643170241. Grid points: 1221
# Iter 18 Diff : 0.0005292710134390255. Grid points: 1221
# Iter 19 Diff : 0.0003581442615532282. Grid points: 1221
# Iter 20 Diff : 0.00024052484952563624. Grid points: 1221
# Iter 21 Diff : 0.00016065441942392233. Grid points: 1221
# Iter 22 Diff : 0.00010686288002537125. Grid points: 1221
# Iter 23 Diff : 7.085380017990417e-05. Grid points: 1221
# Iter 23 Convergence reached
# Elapsed Time: 132.75078582763672
# 100%|███████████████████████████████████████████| 14/14 [09:30<00:00, 40.74s/it]
# Euler Bis TI
# Mean: 0.00854360066623105
# Median: 0.0039049370266404093
# Accuracy (mean E)/Elapsed Time: 6.435819278180424e-05
# Creating df asparse
# Saving TI a-sparse benchmark do disk
# Saving TI a-sparse benchmark from disk

# %%
desired_time = 1
plt.plot(df_TI["dim_state"], df_TI["mean_E_time"]*desired_time, label="TI")
plt.plot(df_TI_sparse["dim_state"], df_TI_sparse["mean_E_time"]*desired_time, label="TI Sparse")
plt.plot(df_TI_a_sparse["dim_state"], df_TI_a_sparse["mean_E_time"]*desired_time, label="TI A-Sparse")
plt.xlabel("dimension state")
plt.ylabel("(Euler error/Elapsed time (sec))*100")
plt.legend()

# %%
desired_accuracy = 0.003892
plt.plot(df_TI["dim_state"], df_TI["time_mean_E"]*desired_accuracy, label="TI")
plt.plot(df_TI_sparse["dim_state"], df_TI_sparse["time_mean_E"]*desired_accuracy, label="TI Sparse")
plt.plot(df_TI_a_sparse["dim_state"], df_TI_a_sparse["time_mean_E"]*desired_accuracy, label="TI A-Sparse")
plt.xlabel("dimension state")
plt.ylabel("Elapsed time (sec)/Euler error")
plt.yscale('log')
plt.legend()

# %%
n = len(df_TI_a_sparse["dim_state"])
data = df_TI_a_sparse["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range

p = plt.scatter(df_TI_a_sparse["time"], df_TI_a_sparse["mean_E"], c=list(df_TI_a_sparse["dim_state"].values), cmap=cmap, s=200, label="Time Iteration A-Sparse")
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
#plt.xscale('log')
#plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))

figname = output_folder + 'Euler_error_time_TI_linear_a_sparse.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %%
n = len(df_TI_a_sparse["dim_state"])
data = df_TI_a_sparse["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range

p = plt.scatter(df_TI_a_sparse["time"], df_TI_a_sparse["mean_E"], c=list(df_TI_a_sparse["dim_state"].values), cmap=cmap, s=200, label="Time Iteration A-Sparse")
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))

figname = output_folder + 'Euler_error_time_TI_log_a_sparse.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %% [markdown]
# ---
# ---
#
# # bc-MC operator with ANNs
#
# Get rid of useless objects that take RAM space.

# %%
# Store parameters
class MyParams():
    """
    N: number of draws for innovation vector
    M: number of draws for the state vector
    lr: learning rate
    pre_train_model: whether or not pre-train the model before starting the full training loop (not used)
    nb_epochs: number of gradient descent steps during training
    bc: borrowing constraint 
    order_gauss: order for the Gaussian quadrature to use when solving with time iteration
    σ_shocks: parameter determining the variance of shocks
    use_Sobol: whether or not use Sobol sampling for the state stapce
    dim_p: number of different pi
    grid_depth: depth of the sparse grid
    nb_refinements: nb refinement for the adaptive sparse grid
    surplus_threshold: surplus threshold to use for the adaptive sparse grid
    name_params: name of params object initialized
    nb_points_w: nb grid points for w grid
    nb_points_other: nb grid points other dimensions
    w1: weight first element loss function
    w2: weight second element loss function
    debug: if True, print info on params when building it
    """
    def __init__(self, N, M, lr, pre_train_model, nb_epochs, 
                 bc, order_gauss, σ_shocks, use_Sobol, 
                 optimizer, dim_p,
                 grid_depth, nb_refinements, surplus_threshold,
                 name_params,
                 nb_points_w=10, nb_points_other=3, 
                 w1 = 0.5, w2 = 0.5,
                 debug=False):
        # savings-consumption with binding constraint
        # Model parameters
        self.β = 0.9 
        self.γ = 2.0
        self.one_min_γ = 1 - self.γ
        self.σ_shocks = σ_shocks #default 0.01
        self.σ_r = self.σ_shocks #0.01
        self.ρ_r = 0.9 #0.2
        self.σ_δ = self.σ_shocks
        self.ρ_δ = 0.9 #0.2
        self.σ_p = self.σ_shocks
        self.ρ_p = 0.9 
        self.rbar = 1.04
        # Level of borrowing constraint
        if isinstance(bc, (int, float)):
            self.bc = bc
            self.bc_torch = torch.tensor([self.bc])
        else:
            raise TypeError("bc_chosen must be a real number (int or float).")       
        # Standard deviations for ergodic distributions of exogenous state variables
        self.σ_e_r = self.σ_r/(1-self.ρ_r**2)**0.5
        self.σ_e_δ = self.σ_δ/(1-self.ρ_δ**2)**0.5
        self.σ_e_p = self.σ_p/(1-self.ρ_p**2)**0.5
        # grids
        self.dim_p = dim_p #(p1, p2, ..., pl)
        self.dim_state = 3 + dim_p #(w ,r, delta, p1, p2, ..., pl)
        self.dim_shock = 2 + dim_p #(e_r, e_delta, e_p1, e_p2, ..., e_pl)
        self.n_points_grid = nb_points_other #nb points for (r, δ, p1, ..., pl)
        self.n_points_w = nb_points_w #10 #nb points for w
        self.r_min = -2*self.σ_e_r 
        self.r_max = 2*self.σ_e_r 
        self.δ_min = -2*self.σ_e_δ
        self.δ_max = 2*self.σ_e_δ
        self.p_min = -2*self.σ_e_p
        self.p_max = 2*self.σ_e_p 
        # bounds for endogenous state variable (cash-in-hand)
        self.wmin = 0.001 #0.1 #4 stdev with bc =0, based on TI. 0.7752188662883139 - 1.3681603157252489
        self.wmax = 3.0 #4.0
        self.w_grid = np.linspace(self.wmin, self.wmax, self.n_points_w)
        self.r_grid = np.linspace(self.r_min, self.r_max, self.n_points_grid)
        self.δ_grid = np.linspace(self.δ_min, self.δ_max, self.n_points_grid)
        self.p_grid = np.linspace(self.p_min, self.p_max, self.n_points_grid)
        # Functions
        self.u = lambda c: (1/self.one_min_γ)*(c**(self.one_min_γ) - 1)
        self.u_prime =  lambda c: c**(-self.γ)
        self.u_prime_inv =  lambda c: c**(-(1/self.γ))
        # Standard shocks
        σ_e = 0.5 #
        μ_e = 0.0 #location parameter shocks
        # Values passed as inputs
        self.N = N #number of draws inside expectation
        self.M = M #number of draws outside expecation
        self.MN = int(M*N)
        # To keep constant the number of function evaluations
        self.T = int((M*N)/2) #number of draws all in on expectation
        # To compare Loss functions
        #self.T = int((M*N)) #number of draws all in on expectation
        self.x_distribution = "Uniform" #"Normal" #Uniform or Normal
        self.σ_e = σ_e
        self.μ_e = μ_e
        self.e_distribution = "Lognormal" #"Normal"
        self.x_low = self.wmin
        self.x_high = self.wmax
        # Vectorized Monte Carlo requires the creation of some objects
        # To repeat vectors
        repeat_vector = torch.ones(N) #to repeat the same value n times using a matrix multiplication
        # To calculate the expectation wrt future shocks using a matrix multiplication
        A = sparse.eye(M) 
        B = sparse.csr_matrix(np.ones(N)/N)
        # Sparse kronecker product. Then convert to pytorch sparse
        # W used using the sum((sum)^2) formula
        W = sparse_mx_to_torch_sparse_tensor(sparse.kron(A, B))
        self.repeat_vector = repeat_vector
        self.W = W  
        # W used using the 2/N(N-1) sum() formula
        self.W_expanded = create_W_expanded_matrix(self.M, self.N)
        # Learning parameters
        self.lr = lr
        self.momentum = 0.9 #momentum for SGD with momentum
        self.lr_pre_train = 1e-3 #learning rate during pre-training
        self.optimizer = optimizer #"Adam" #default: #Adam or SGD or SWA
        self.freq_gamma = 0.95 #0.85
        self.use_scheduler = False #default: True
        self.pre_train_model = pre_train_model #default: True
        self.nb_epochs = nb_epochs
        self.nb_epochs_pre_train = int(self.nb_epochs/1)
        self.freq_scheduler = 1000 #int(self.nb_epochs/10)
        # Sobol sampling
        self.soboleng = torch.quasirandom.SobolEngine(dimension=1) #sobol draws for income
        self.use_Sobol = use_Sobol #Sobol for dimension M
        self.use_Sobol_T = use_Sobol #Sobol for all-in-one
        # DEBUG PARAMS
        self.error_correction=True #error correction for the model
        self.selective_error_correction=False #error correction for the model, only if give positive values
        self.abs_value=False
        self.perfect_forecast = False
        self.fake_bias=0.0
        # GAUSSIAN QUADRATURE
        # value e_r, e_δ, e_p1, e_p2, ..., e_pl
        strr = "chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ)"
        # add p1, ..., pl
        for i in range(0, dim_p): 
            strr = strr + ',' + "chaospy.Normal(0, self.σ_p)"
        if debug==True:
            print("Quadrature grid build for: {}".format(strr)) #debug
        self.distrib = eval('chaospy.J({})'.format(strr))
        #self.distrib = chaospy.J(chaospy.Normal(0, self.σ_r), chaospy.Normal(0, self.σ_δ), chaospy.Normal(0, self.σ_p))
        self.order_gauss = order_gauss
        nodes, weights = dist(self.order_gauss, self.distrib, rule = "gaussian", sp=True)
        self.nodes = nodes
        self.weights = weights
        self.weights_torch = torch.tensor(weights)
        self.nodes_torch = torch.tensor(np.transpose(self.nodes)) #column=dim. Row=observation
        # SCALE OF THE OBJECTIVE FUNCTION
        self.nb_points_test = 1000
        self.xvec_test_torch = torch.linspace(self.x_low, self.x_high, self.nb_points_test).unsqueeze(1) #add a dimension
        self.xvec_test = self.xvec_test_torch.numpy()
        self.swa_start = 1000
        self.swa_freq= 10
        def identity_function(x):
            return x
        self.c_function_TI = identity_function #Initialization TI solution, interpolated
        self.ss = np.ones(self.dim_state) #steady-state value
        # Parameters for the adaptive sparse grid
        self.grid_depth = grid_depth # Initial depth of the sparse grid
        self.nb_refinements = nb_refinements # Nb of refinement steps for the sparse grid
        self.surplus_threshold = surplus_threshold #
        self.grid_dim = 3 + self.dim_p # Dimension input: (w, r, delta, vector ps)
        self.grid_out = 1 # Dimension output
        self.grid_order = 1 #1 # 1=linear, 2=quadratic, 3=cubic
        self.grid_rule = "localp" # Type of base functions
        # Need to set the domain
        ## 2 columns: min, max
        ## rows: corresponding to a variable
        ## Order: w, r, delta, p1, p2, ..., pn
        self.domain_transform = np.zeros((self.grid_dim, 2))
        self.domain_transform[0,:] = np.array([self.wmin, self.wmax])
        self.domain_transform[1,:] = np.array([self.r_min, self.r_max])
        self.domain_transform[2,:] = np.array([self.δ_min, self.δ_max])
        # max and min for the ps:
        self.domain_transform[3:,:] = np.array([self.p_min, self.p_max])
        # Store grid that is updating during time iteration
        self.grid_old = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth, self.grid_order, self.grid_rule)
        self.grid_old.setDomainTransform(self.domain_transform)
        self.grid_old_points = self.grid_old.getPoints() # Points of the grid
        # Let's store another grid to test for convergence of the time iteration algo
        self.grid_depth_test = 2
        self.grid_test = Tasmanian.makeLocalPolynomialGrid(self.grid_dim, self.grid_out, self.grid_depth_test, self.grid_order, self.grid_rule)
        self.grid_test.setDomainTransform(self.domain_transform)
        self.grid_test_points = self.grid_old.getPoints()
        # To store sparse solution
        self.c_grid_TI_sparse = np.zeros((self.grid_old_points.shape[0],1))
        self.c_function_TI_sparse = identity_function # Initialization TI solution, using sparse grid
        # weights in the loss function
        self.w1 = w1
        self.w2 = w2
        # Check bad combination
        if (self.optimizer == "SWA") & (self.use_scheduler == True):
            raise('opt SWA and use_schedule = True')

# %%
M_chosen = 100 #100 #100 #25 #100 #200 # 50 #outer expectation
N_chosen = 2 #8 #2 #4 # Inner expectation
lr_chosen = 1e-3
pre_train_model_chosen = False
nb_epochs_chosen = 10000 #10000
σ_shocks_chosen = 0.01
use_Sobol_chosen = False
optimizer_chosen = "Adam"
dim_p_chosen =  2 #Default is 2 (p and q, as in section 4.2)
# Parameters for the sparse grid
grid_depth_chosen = 2
nb_refinements_chosen = 2
surplus_threshold_chosen = 1e-4
name_params = "params_MC"
w1_chosen = 0.5
w2_chosen = 0.5

# REMARK:
# for the dense grid, to change the number of points on w-grid, change self.n_points_w = 10
# to change the number of points for the other dimensions, change self.n_points_grid = 3
params = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen,
                  nb_epochs_chosen, bc_chosen, order_gauss,
                  σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen,
                  dim_p_chosen, grid_depth_chosen, 
                  nb_refinements_chosen, surplus_threshold_chosen,
                  name_params, nb_points_w=10, nb_points_other=3,
                  w1 = w1_chosen, w2 = w2_chosen)

show_params(params)

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    """
    Output share of cash-on-hand consumed, and lagrange multiplier
    """
    def __init__(self, params):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.dim_state = params.dim_state
        self.nb_nodes = 32 #32 default
        self.act_f = nn.ReLU() #nn.ReLU()  #nn.ReLU() #nn.LeakyReLU() #nn.Tanh() #
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(self.dim_state, self.nb_nodes),
            self.act_f,
            nn.Linear(self.nb_nodes, self.nb_nodes),
            self.act_f,
            nn.Linear(self.nb_nodes, 2)
        )

    def forward(self, x):
        y = self.linear_relu_stack(x)
        return y

model_MC = NeuralNetwork(params).to(device)
print(model_MC)

# Grid M and grid N
T = (params.M*params.N)/2
# Non-evenly spaced grid
grid_N = np.array([N for N in range(2, params.T+2, 2)])
grid_M = 2*T/grid_N

is_int = grid_M % 1 == 0
grid_N = grid_N[is_int]
grid_M = grid_M[is_int]

print(grid_N)
print(grid_M)
print(grid_N*grid_M)

# Pre-calculate list of params
# Used when optimally chosing N during training
list_params = []
for (ind, (N_loop, M_loop)) in enumerate(zip(grid_N, grid_M)):
    # Change M and N
    params_local = MyParams(int(N_loop), int(M_loop), params.lr, 
              params.pre_train_model,
              params.nb_epochs, params.bc, params.order_gauss,
              params.σ_shocks, params.use_Sobol, params.optimizer,
              params.dim_p, params.grid_depth,
              params.nb_refinements, params.surplus_threshold,
              "params_MC", params.n_points_w, params.n_points_grid,
              params.w1, params.w2)
    list_params.append(params_local)
# Out:
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# [  2   4   8  10  20  40  50 100]
# [100.  50.  25.  20.  10.   5.   4.   2.]
# [200. 200. 200. 200. 200. 200. 200. 200.]

# %%
with torch.no_grad():
    v = Ξ_torch_MC(model_MC, params)
print(v)
# Out:
# tensor(0.1939)

# %%
nb_draws = 10000 #nb draws when calculating variance of loss
seed=123
np.random.seed(seed)
torch.manual_seed(seed)

model_MC.train()

# Optimizer
optimizer = create_optimizer(model_MC, params.optimizer, params.lr, params.momentum)
# Scheduler
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=params.freq_gamma)

loss_epochs_MC = torch.zeros(params.nb_epochs)
list_Euler_median = [] #store median abs value percentage error
list_Euler_mean = [] #mean
list_Euler_max = [] #max
list_Euler_std = [] #std
list_Euler_i = [] #store index i
list_Euler_loss = [] #store loss
calculate_variance_loss = True # Calculate variance of loss or not
list_var_loss = [] #store variance of the loss
list_optimal_N = [] #store the optimal N
list_optimal_N_current = [] #store the current optimal N used.
optimal_N = params.N #set initial choice for N
index_best_N = np.where(grid_N == optimal_N)[0][0]
freq_var =  50 #frequency with which the variance of the loss is calculated
freq_loss = 50 #frequency with which the loss is calculated
ratio_freq_loss_freq_var = int(freq_var/freq_loss)
use_N_star = True #Vary N during training
use_exact_accuracy_metrics = False #True # If False, use square loss to get the EEE
min_euler_bis = float('inf')
best_model = copy.deepcopy(model_MC)

for i in tqdm(range(0, params.nb_epochs)):
    # Clear gradient
    optimizer.zero_grad()
    # params associated with the current best N:
    params_local = list_params[index_best_N]
    # Calculate loss
    loss = Ξ_torch_MC(model_MC, params_local)
    loss_epochs_MC[[i]] = float(loss.item())

    # Backpropagation
    loss.backward()
    # Avoid explosive gradients
    clip_grad_norm_(model_MC.parameters(), max_norm=1.0, error_if_nonfinite=False)
    # Gradient descent step
    optimizer.step()

    if i % freq_loss == 0: #Monitor accuracy
        model_MC.eval()
        list_optimal_N_current.append(optimal_N) #N used
        # Evaluate Euler error
        if use_exact_accuracy_metrics == True:
            with torch.no_grad():
                euler, euler_bis, c, c_RHS, w = evaluate_accuracy_pytorch_MC_frozen(model_MC, params_local)
            list_Euler_median.append(np.median(euler_bis))
            list_Euler_mean.append(np.mean(euler_bis))
            list_Euler_max.append(np.max(euler_bis))
            list_Euler_std.append(np.std(euler_bis))
        # Square root of loss function
        else:
            euler_bis = float(loss.item())**0.5
            list_Euler_mean.append(euler_bis)
        list_Euler_i.append(i) #Index
        list_Euler_loss.append(float(loss.item())) #loss
        model_MC.train()
        # Check if current model is better
        mean_euler_bis = np.mean(euler_bis)
        if mean_euler_bis < min_euler_bis:
            min_euler_bis = mean_euler_bis
            best_model = copy.deepcopy(model_MC)
    # Calculation of variance of the loss and optimal choice for N
    if (calculate_variance_loss == True) & (i % freq_var == 0): #calculate variance of loss
        var_loss_formula, var_f, cov_f = calculate_variance_gaussian(params_local, model_MC, nb_draws, grid_M, grid_N)
        if use_N_star == False:
            index_best_N_dummy = np.argmin(var_loss_formula)
            optimal_N_dummy = grid_N[index_best_N_dummy] #Do not modify optimal_N
            list_optimal_N.append(optimal_N_dummy)
            list_var_loss.append(var_loss_formula[index_best_N])
        # When N* algo is used, update the value of N during training
        else:
            # Gaussian formula
            index_best_N = np.argmin(var_loss_formula)
            # Var/Cov
            #N_star_theory = 1 + np.abs(var_f/cov_f)
            #index_best_N = np.argmin(np.abs(N_star_theory - grid_N)) #project on grid
            optimal_N = grid_N[index_best_N]
            list_optimal_N.append(optimal_N)
            list_var_loss.append(var_loss_formula[index_best_N])
    if i % 1000 == 0:
        loss, current = float(loss.item()), i
        print(f"loss: {loss:>7f}, N used: {list_optimal_N_current[-1]}, N*: {list_optimal_N[-1]}, mean euler error {list_Euler_mean[-1]:>7f}, [{current:>5d}/{params.nb_epochs:>5d}]")
    if (i % params.freq_scheduler == 0) & (i != 0) & (params.use_scheduler == True):
        scheduler.step()
        print("i : {}. Decreasing learning rate: {}".format(i, scheduler.get_last_lr()))

if params.optimizer == "SWA":
    optimizer.swap_swa_sgd()
# Out:
#   1%|▏                                      | 56/10000 [00:00<00:35, 280.27it/s]
# loss: 0.170174, N used: 2, N*: 2, mean euler error 0.412521, [    0/10000]
#  11%|███▉                                 | 1060/10000 [00:03<00:27, 328.07it/s]
# loss: 0.000490, N used: 2, N*: 2, mean euler error 0.022128, [ 1000/10000]
#  21%|███████▋                             | 2061/10000 [00:06<00:22, 345.81it/s]
# loss: 0.000187, N used: 4, N*: 2, mean euler error 0.013686, [ 2000/10000]
#  31%|███████████▎                         | 3058/10000 [00:09<00:19, 353.82it/s]
# loss: 0.000142, N used: 4, N*: 4, mean euler error 0.011934, [ 3000/10000]
#  41%|███████████████                      | 4072/10000 [00:12<00:16, 356.42it/s]
# loss: 0.000052, N used: 4, N*: 8, mean euler error 0.007202, [ 4000/10000]
#  51%|██████████████████▋                  | 5066/10000 [00:15<00:14, 344.44it/s]
# loss: 0.000079, N used: 8, N*: 8, mean euler error 0.008900, [ 5000/10000]
#  61%|██████████████████████▍              | 6058/10000 [00:17<00:11, 341.83it/s]
# loss: 0.000093, N used: 8, N*: 8, mean euler error 0.009622, [ 6000/10000]
#  71%|██████████████████████████▏          | 7068/10000 [00:20<00:09, 323.53it/s]
# loss: 0.000058, N used: 20, N*: 4, mean euler error 0.007637, [ 7000/10000]
#  81%|█████████████████████████████▊       | 8071/10000 [00:23<00:05, 347.21it/s]
# loss: 0.000079, N used: 20, N*: 10, mean euler error 0.008911, [ 8000/10000]
#  91%|█████████████████████████████████▍   | 9053/10000 [00:26<00:02, 319.82it/s]
# loss: 0.000061, N used: 20, N*: 4, mean euler error 0.007836, [ 9000/10000]
# 100%|████████████████████████████████████| 10000/10000 [00:29<00:00, 337.60it/s]

# %%
rate = 10
plt.plot(list_Euler_loss, label="Loss")
plt.plot(pd.Series(list_Euler_loss).rolling(rate).mean(), label="MA Loss")
plt.plot(pd.Series(list_Euler_mean).rolling(rate).mean(), label="MA mean euler error")
plt.xlabel("Gradient descent steps")
plt.ylabel("Value")
plt.yscale('log')
plt.legend()
plt.show()

rate_rolling = 10
max_N = len(list_optimal_N)
plt.plot(pd.Series(list_optimal_N[:max_N]), label="N*", alpha=0.3)
plt.plot(pd.Series(list_optimal_N[:max_N]).rolling(rate_rolling).mean(), label=f"MA({rate_rolling}) mean N*")
plt.plot(pd.Series(list_optimal_N[:max_N]).rolling(rate_rolling).median(), label=f"MA({rate_rolling}) median N*")
plt.xlabel("Iterations")
plt.ylabel("Optimal N")
plt.legend()
# Out:
# /home/julien/.local/lib/python3.8/site-packages/pandas/core/window/rolling.py:368: ComplexWarning: Casting complex values to real discards the imaginary part
#   values = ensure_float64(values)

# %%
# Test approximation
model_MC.eval()

# Define the grid
nb_points = 100
with torch.no_grad():
    wvec_eval = torch.linspace(params.wmin, params.wmax, nb_points)
    rvec_eval = 0*torch.ones(nb_points) #torch.linspace(grid.σ_e_r_min, grid.σ_e_r_max, nb_points) #torch.zeros(nb_points)
    ps_vec_eval = 0*torch.ones(nb_points, params.dim_p) #torch.zeros(nb_points)
    δvec_eval = 0*torch.ones(nb_points) #torch.zeros(nb_points)

    # To store vaules
    ζvec = torch.zeros(nb_points)
    hvec = torch.zeros(nb_points)
    cvec = torch.zeros(nb_points)

    # state
    # order: w, r, delta, p1, ..., pl
    # last model
    cvec_MC, hvec_MC = model_normalized(model_MC, wvec_eval, rvec_eval, δvec_eval, ps_vec_eval, params)
    # best model
    cvec_MC_best, hvec_MC_best = model_normalized(best_model, wvec_eval, rvec_eval, δvec_eval, ps_vec_eval, params)
    
    # Save for latter use
    cvec_MC_bc_0, hvec_MC_bc_0 = cvec_MC.detach().numpy(), hvec_MC.detach().numpy()
    cvec_MC_best_bc_0, hvec_MC_best_bc_0 = cvec_MC_best.detach().numpy(), hvec_MC_best.detach().numpy()

# Plot the result
len_wec = params_sparse.nb_points_test

plt.title("Multidimensional Consumption-Savings (decision rule)")
plt.plot(wvec_eval, wvec_eval, linestyle='--', color='black')
plt.plot(wvec_eval.detach().numpy(), cvec_MC.detach().numpy(), label="c(w) bc-MC")
plt.plot(wvec_eval.detach().numpy(), cvec_MC_best.detach().numpy(), label="c(w) bc-MC best")
plt.xlabel("$w_t$")
plt.ylabel("$c_t$")
plt.legend()
plt.show()

# %% [markdown]
# ### Accuracy

# %%
model_MC.eval()

# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_pytorch_MC(best_model, 1000, 1000, params)

print("Euler MC")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("Euler Bis MC")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./100)
plt.scatter(w, euler_bis, alpha=0.1)
plt.plot(smoothed[:,0], smoothed[:,1])
# Out:
# Euler MC
# Mean: 0.004847333766520023
# Median: 0.002999633550643921
# Min: 4.172325134277344e-07
# Max: 0.044269025325775146
# std dev.: 0.006729090120643377
# Euler Bis MC
# Mean: 0.0024454512167721987
# Median: 0.001499861478805542
# Min: 1.1920928955078125e-07
# Max: 0.022897720336914062
# std dev.: 0.003444639965891838

# %%
model_MC.eval()

# Evaluate accuracy 
euler, euler_bis, c, c_RHS, w = evaluate_accuracy_pytorch_Gaussian(best_model, 2000, params)

print("Euler MC")
print("Mean: {}".format(np.mean(np.abs(euler))))
print("Median: {}".format(np.median(np.abs(euler))))
print("Min: {}".format(np.min(np.abs(euler))))
print("Max: {}".format(np.max(np.abs(euler))))
print("std dev.: {}".format(np.std(np.abs(euler))))

# Should take the mean of the absolute value
print("Euler Bis MC")
print("Mean: {}".format(np.mean(np.abs(euler_bis))))
print("Median: {}".format(np.median(np.abs(euler_bis))))
print("Min: {}".format(np.min(np.abs(euler_bis))))
print("Max: {}".format(np.max(np.abs(euler_bis))))
print("std dev.: {}".format(np.std(np.abs(euler_bis))))

# Smoothed conditional mean
smoothed = lowess(euler_bis, w, frac=1./100)
plt.scatter(w, euler_bis, alpha=0.1)
plt.plot(smoothed[:,0], smoothed[:,1])
# Out:
# Euler MC
# Mean: 0.009819980710744858
# Median: 0.005478084087371826
# Min: 1.3113021850585938e-06
# Max: 0.08385181427001953
# std dev.: 0.013506353832781315
# Euler Bis MC
# Mean: 0.00500109326094389
# Median: 0.002736121416091919
# Min: 5.960464477539062e-07
# Max: 0.04476141929626465
# std dev.: 0.0070543913170695305

# %% [markdown]
# ## Vary dimension of model

# %%
M_chosen = 100 #100 #100 #25 #100 #200 # 50 #outer expectation
N_chosen = 2 #8 #2 #4 # Inner expectation
lr_chosen = 1e-3
pre_train_model_chosen = False
nb_epochs_chosen = 10000 #10000
σ_shocks_chosen = 0.01
use_Sobol_chosen = False
optimizer_chosen = "Adam"
dim_p_chosen =  2 #Default is 2 (p and q, as in section 4.2)
# Parameters for the sparse grid
grid_depth_chosen = 2
nb_refinements_chosen = 2
surplus_threshold_chosen = 1e-4
name_params = "params_MC"
w1_chosen = 0.5
w2_chosen = 0.5

seed=123
np.random.seed(seed)
torch.manual_seed(seed)

list_dim_p = list(range(1, 15)) #Version Paper
list_elapsed_time_MC = []
list_median_euler_error = []
list_mean_euler_error = []

#parameters for the ANN
#number of different trainings, holding the initial values cst
nb_rep = 1
rate_Euler_error = 10 #take the last 10 values of the Euler Error, then take the mean value
nb_epochs_chosen = 10000 #nb epochs
nb_draws = 10000 #nb draws when calculating variance of loss

if benchmark_MC == True:
    print("Benchmarking bc-MC")
    for dim_p in tqdm(list_dim_p):    
        # Params
        #----------------------------------
        # vary dim_p
        params = MyParams(N_chosen, M_chosen, lr_chosen, pre_train_model_chosen,
                      nb_epochs_chosen, bc_chosen, order_gauss,
                      σ_shocks_chosen, use_Sobol_chosen, optimizer_chosen,
                      dim_p, grid_depth_chosen, 
                      nb_refinements_chosen, surplus_threshold_chosen,
                      name_params, nb_points_w=10, nb_points_other=3,
                      w1 = w1_chosen, w2 = w2_chosen)

        show_params(params)

        # Grid M and grid N
        T = (params.M*params.N)/2
        # Non-evenly spaced grid
        grid_N = np.array([N for N in range(2, params.T+2, 2)])
        grid_M = 2*T/grid_N

        is_int = grid_M % 1 == 0
        grid_N = grid_N[is_int]
        grid_M = grid_M[is_int]

        # Pre-calculate list of params
        # Used when optimally chosing N during training
        list_params = []
        for (ind, (N_loop, M_loop)) in enumerate(zip(grid_N, grid_M)):
            # Change M and N
            params_local = MyParams(int(N_chosen), int(M_chosen), params.lr, 
                      params.pre_train_model,
                      params.nb_epochs, params.bc, params.order_gauss,
                      params.σ_shocks, params.use_Sobol, params.optimizer,
                      params.dim_p, params.grid_depth,
                      params.nb_refinements, params.surplus_threshold,
                      "params_MC", params.n_points_w, params.n_points_grid,
                      params.w1, params.w2)
            list_params.append(params_local)

        # Create new model
        model_MC = NeuralNetwork(params).to(device)
        print(model_MC)
        # Train Model
        model_MC.train()

        # Optimizer
        optimizer = create_optimizer(model_MC, params.optimizer, params.lr, params.momentum)
        # Scheduler
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=params.freq_gamma)

        loss_epochs_MC = torch.zeros(params.nb_epochs)
        list_Euler_median = [] #store median abs value percentage error
        list_Euler_mean = [] #mean
        list_Euler_max = [] #max
        list_Euler_std = [] #std
        list_Euler_i = [] #store index i
        list_Euler_loss = [] #store loss
        calculate_variance_loss = True # Calculate variance of loss or not
        list_var_loss = [] #store variance of the loss
        list_optimal_N = [] #store the optimal N
        list_optimal_N_current = [] #store the current optimal N used.
        optimal_N = params.N #set initial choice for N
        index_best_N = np.where(grid_N == optimal_N)[0][0]
        freq_var =  50 #frequency with which the variance of the loss is calculated
        freq_loss = 50 #frequency with which the loss is calculated
        ratio_freq_loss_freq_var = int(freq_var/freq_loss)
        use_N_star = True #Vary N during training
        use_exact_accuracy_metrics = False # False, use square loss to get the EEE
        min_euler_bis = float('inf')
        best_model = copy.deepcopy(model_MC)

        start = time.time()
        for i in range(0, params.nb_epochs):
            # Clear gradient
            optimizer.zero_grad()
            # params associated with the current best N:
            params_local = list_params[index_best_N]
            # Calculate loss
            loss = Ξ_torch_MC(model_MC, params_local)
            loss_epochs_MC[[i]] = float(loss.item())

            # Backpropagation
            loss.backward()
            # Avoid explosive gradients
            clip_grad_norm_(model_MC.parameters(), max_norm=1.0, error_if_nonfinite=False)
            # Gradient descent step
            optimizer.step()

            if i % freq_loss == 0: #Monitor accuracy
                model_MC.eval()
                list_optimal_N_current.append(optimal_N) #N used
                # Evaluate Euler error
                if use_exact_accuracy_metrics == True:
                    with torch.no_grad():
                        euler, euler_bis, c, c_RHS, w = evaluate_accuracy_pytorch_MC_frozen(model_MC, params_local)
                    list_Euler_median.append(np.median(euler_bis))
                    list_Euler_mean.append(np.mean(euler_bis))
                    list_Euler_max.append(np.max(euler_bis))
                    list_Euler_std.append(np.std(euler_bis))
                # Square root of loss function
                else:
                    euler_bis = float(loss.item())**0.5
                    list_Euler_mean.append(euler_bis)
                list_Euler_i.append(i) #Index
                list_Euler_loss.append(float(loss.item())) #loss
                model_MC.train()
                # Check if current model is better
                mean_euler_bis = np.mean(euler_bis)
                if mean_euler_bis < min_euler_bis:
                    min_euler_bis = mean_euler_bis
                    best_model = copy.deepcopy(model_MC)
            # Calculation of variance of the loss and optimal choice for N
            if (calculate_variance_loss == True) & (i % freq_var == 0): #calculate variance of loss
                var_loss_formula, var_f, cov_f = calculate_variance_gaussian(params_local, model_MC, nb_draws, grid_M, grid_N)
                if use_N_star == False:
                    index_best_N_dummy = np.argmin(var_loss_formula)
                    optimal_N_dummy = grid_N[index_best_N_dummy] #Do not modify optimal_N
                    list_optimal_N.append(optimal_N_dummy)
                    list_var_loss.append(var_loss_formula[index_best_N])
                # When N* algo is used, update the value of N during training
                else:
                    # Gaussian formula
                    index_best_N = np.argmin(var_loss_formula)
                    # Var/Cov
                    #N_star_theory = 1 + np.abs(var_f/cov_f)
                    #index_best_N = np.argmin(np.abs(N_star_theory - grid_N)) #project on grid
                    optimal_N = grid_N[index_best_N]
                    list_optimal_N.append(optimal_N)
                    list_var_loss.append(var_loss_formula[index_best_N])
            if i % 5000 == 0:
                loss, current = float(loss.item()), i
                print(f"loss: {loss:>7f}, N used: {list_optimal_N_current[-1]}, N*: {list_optimal_N[-1]}, mean euler error {list_Euler_mean[-1]:>7f}, [{current:>5d}/{params.nb_epochs:>5d}]")
            if (i % params.freq_scheduler == 0) & (i != 0) & (params.use_scheduler == True):
                scheduler.step()
                print("i : {}. Decreasing learning rate: {}".format(i, scheduler.get_last_lr()))

        if params.optimizer == "SWA":
            optimizer.swap_swa_sgd()
          
        end = time.time()
        elasped_time = end - start
        print("Elapsed Time: {}".format(elasped_time))
        
        
        # Measure accuracy
        euler, euler_bis, c, c_RHS, w = evaluate_accuracy_pytorch_Gaussian(best_model, nb_draws_gaussian, params)
        # Should take the mean of the absolute value
        median_E = np.median(np.abs(euler_bis))
        mean_E = np.mean(np.abs(euler_bis))
        print("Euler Bis TI")
        print("Mean: {}".format(mean_E))
        print("Median: {}".format(median_E))

        print("Accuracy (mean E)/Elapsed Time: {}".format(mean_E/elasped_time))
        list_elapsed_time_MC.append(elasped_time)
        list_median_euler_error.append(median_E)
        list_mean_euler_error.append(mean_E)
        
    print("Creating dataframe")
    df_MC = pd.DataFrame({"time": list_elapsed_time_MC,
                      "median_E": list_median_euler_error,
                      "mean_E": list_mean_euler_error,
                      "dim_p": list_dim_p})

    df_MC["mean_E_time"] = df_MC["mean_E"].div(df_MC["time"])
    df_MC["time_mean_E"] = df_MC["time"].div(df_MC["mean_E"])
    df_MC["dim_state"] = df_MC["dim_p"] + 3
    df_MC["label"] = "bc-MC"

    # Save and load files
    if save_csv_file_MC == True: #When testing time-accuracy, save results to .csv
        df_MC.to_csv(output_folder + 'df_MC_dims.csv', index=False)

if load_csv_file_MC == True: #When testing time-accuracy, save results to .csv
    df_MC = pd.read_csv(output_folder + 'df_MC_dims.csv')
# Out:
# Benchmarking bc-MC
#   0%|                                                    | 0/14 [00:00<?, ?it/s]
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.162197, N used: 2, N*: 2, mean euler error 0.402737, [    0/10000]
# loss: 0.000031, N used: 10, N*: 8, mean euler error 0.005541, [ 5000/10000]
#   7%|███▏                                        | 1/14 [00:34<07:29, 34.59s/it]
# Elapsed Time: 33.987308979034424
# Euler Bis TI
# Mean: 0.0039035656955093145
# Median: 0.002291381359100342
# Accuracy (mean E)/Elapsed Time: 0.00011485362662625885
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=5, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.171029, N used: 2, N*: 2, mean euler error 0.413556, [    0/10000]
# loss: 0.000058, N used: 8, N*: 10, mean euler error 0.007634, [ 5000/10000]
#  14%|██████▎                                     | 2/14 [01:08<06:48, 34.05s/it]
# Elapsed Time: 32.78942894935608
# Euler Bis TI
# Mean: 0.002698596566915512
# Median: 0.0016863346099853516
# Accuracy (mean E)/Elapsed Time: 8.230081015084305e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=6, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.254918, N used: 2, N*: 2, mean euler error 0.504894, [    0/10000]
# loss: 0.000095, N used: 10, N*: 8, mean euler error 0.009743, [ 5000/10000]
#  21%|█████████▍                                  | 3/14 [01:39<05:59, 32.72s/it]
# Elapsed Time: 30.22488260269165
# Euler Bis TI
# Mean: 0.003579898737370968
# Median: 0.002033144235610962
# Accuracy (mean E)/Elapsed Time: 0.00011844210561308063
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=7, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.232795, N used: 2, N*: 2, mean euler error 0.482489, [    0/10000]
# loss: 0.000062, N used: 8, N*: 8, mean euler error 0.007852, [ 5000/10000]
#  29%|████████████▌                               | 4/14 [02:12<05:29, 32.98s/it]
# Elapsed Time: 32.54812216758728
# Euler Bis TI
# Mean: 0.005412905476987362
# Median: 0.003633826971054077
# Accuracy (mean E)/Elapsed Time: 0.00016630469337422326
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=8, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.291931, N used: 2, N*: 2, mean euler error 0.540306, [    0/10000]
# loss: 0.000087, N used: 8, N*: 8, mean euler error 0.009322, [ 5000/10000]
#  36%|███████████████▋                            | 5/14 [02:45<04:55, 32.87s/it]
# Elapsed Time: 31.415647268295288
# Euler Bis TI
# Mean: 0.008992635644972324
# Median: 0.0057032108306884766
# Accuracy (mean E)/Elapsed Time: 0.0002862470274183306
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.153842, N used: 2, N*: 2, mean euler error 0.392226, [    0/10000]
# loss: 0.000198, N used: 10, N*: 10, mean euler error 0.014067, [ 5000/10000]
#  43%|██████████████████▊                         | 6/14 [03:20<04:27, 33.46s/it]
# Elapsed Time: 33.40993690490723
# Euler Bis TI
# Mean: 0.0029882602393627167
# Median: 0.0015925765037536621
# Accuracy (mean E)/Elapsed Time: 8.944225928555416e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.155843, N used: 2, N*: 2, mean euler error 0.394770, [    0/10000]
# loss: 0.000072, N used: 20, N*: 10, mean euler error 0.008510, [ 5000/10000]
#  50%|██████████████████████                      | 7/14 [03:53<03:53, 33.31s/it]
# Elapsed Time: 31.685221910476685
# Euler Bis TI
# Mean: 0.0027699668426066637
# Median: 0.001491546630859375
# Accuracy (mean E)/Elapsed Time: 8.742141211549404e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.181155, N used: 2, N*: 2, mean euler error 0.425623, [    0/10000]
# loss: 0.000132, N used: 20, N*: 10, mean euler error 0.011507, [ 5000/10000]
#  57%|█████████████████████████▏                  | 8/14 [04:27<03:21, 33.58s/it]
# Elapsed Time: 32.61137795448303
# Euler Bis TI
# Mean: 0.004250046331435442
# Median: 0.002592027187347412
# Accuracy (mean E)/Elapsed Time: 0.00013032403406465672
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=12, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.382595, N used: 2, N*: 2, mean euler error 0.618542, [    0/10000]
# loss: 0.000120, N used: 10, N*: 10, mean euler error 0.010941, [ 5000/10000]
#  64%|████████████████████████████▎               | 9/14 [05:01<02:48, 33.78s/it]
# Elapsed Time: 32.756439447402954
# Euler Bis TI
# Mean: 0.004975654184818268
# Median: 0.0027112364768981934
# Accuracy (mean E)/Elapsed Time: 0.0001518985051109624
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=13, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.111158, N used: 2, N*: 2, mean euler error 0.333404, [    0/10000]
# loss: 0.000135, N used: 20, N*: 10, mean euler error 0.011624, [ 5000/10000]
#  71%|██████████████████████████████▋            | 10/14 [05:36<02:16, 34.10s/it]
# Elapsed Time: 33.229289054870605
# Euler Bis TI
# Mean: 0.0034628594294190407
# Median: 0.0020377933979034424
# Accuracy (mean E)/Elapsed Time: 0.00010421105981837037
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=14, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.147312, N used: 2, N*: 2, mean euler error 0.383812, [    0/10000]
# loss: -0.000056, N used: 20, N*: 20, mean euler error 0.000000+0.007490j, [ 5000/10000]
#  79%|█████████████████████████████████▊         | 11/14 [06:11<01:43, 34.35s/it]
# Elapsed Time: 33.0196807384491
# Euler Bis TI
# Mean: 0.0030056973919272423
# Median: 0.0018360912799835205
# Accuracy (mean E)/Elapsed Time: 9.102745165029166e-05
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=15, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.112574, N used: 2, N*: 2, mean euler error 0.335520, [    0/10000]
# loss: 0.000221, N used: 20, N*: 10, mean euler error 0.014867, [ 5000/10000]
#  86%|████████████████████████████████████▊      | 12/14 [06:46<01:09, 34.71s/it]
# Elapsed Time: 33.527937173843384
# Euler Bis TI
# Mean: 0.003777567995712161
# Median: 0.002250194549560547
# Accuracy (mean E)/Elapsed Time: 0.00011266926372849469
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.217519, N used: 2, N*: 2, mean euler error 0.466389, [    0/10000]
# loss: 0.000505, N used: 10, N*: 10, mean euler error 0.022477, [ 5000/10000]
#  93%|███████████████████████████████████████▉   | 13/14 [07:20<00:34, 34.43s/it]
# Elapsed Time: 31.78422474861145
# Euler Bis TI
# Mean: 0.00730527937412262
# Median: 0.004581153392791748
# Accuracy (mean E)/Elapsed Time: 0.00022983978473288904
# learning rate: 0.001
# nb epochs: 10000
# W.shape: torch.Size([100, 200])
# W_expanded.shape: torch.Size([200, 200])
# M: 100
# N: 2
# MN: 200
# T: 100
# T: False
# Budget constraint: 0
# σ_shocks: 0.01
# use_Sobol: False
# optimizer_chosen: Adam
# use_scheduler: False
# grid_depth_chosen: 2
# grid_depth_chosen: 2
# surplus_threshold_chosen: 0.0001
# w1: 0.5
# w2: 0.5
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (act_f): ReLU()
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=17, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# loss: 0.168936, N used: 2, N*: 2, mean euler error 0.411018, [    0/10000]
# loss: -0.000008, N used: 8, N*: 10, mean euler error 0.000000+0.002830j, [ 5000/10000]
# 100%|███████████████████████████████████████████| 14/14 [07:55<00:00, 33.98s/it]
# Elapsed Time: 33.12829113006592
# Euler Bis TI
# Mean: 0.003974653780460358
# Median: 0.0023843348026275635
# Accuracy (mean E)/Elapsed Time: 0.00011997762772777374
# Creating dataframe

# %%
df_merged = pd.concat([df_TI, df_MC])
df_merged.head(10)
# Out:
#          time  median_E    mean_E  dim_p  mean_E_time    time_mean_E  \
# 0    7.995708  0.000785  0.002655      1     0.000332    3011.470322
# 1    6.335501  0.000890  0.002903      2     0.000458    2182.128545
# 2   25.134836  0.000954  0.002964      3     0.000118    8479.035607
# 3   78.033718  0.001068  0.003332      4     0.000043   23418.645369
# 4  255.662635  0.001159  0.003501      5     0.000014   73026.728238
# 5  999.983547  0.001230  0.003672      6     0.000004  272345.130144
# 0   33.987309  0.002291  0.003904      1     0.000115    8706.734209
# 1   32.789429  0.001686  0.002699      2     0.000082   12150.548678
# 2   30.224883  0.002033  0.003580      3     0.000118    8442.943452
# 3   32.548122  0.003634  0.005413      4     0.000166    6013.059401
#
#    dim_state  label  log_dim_state  log_time  mean_E_pred   time_pred
# 0          4     TI       1.386294  2.078905     0.002602    4.035560
# 1          5     TI       1.609438  1.846169     0.002885   11.407734
# 2          6     TI       1.791759  3.224255     0.003116   32.247418
# 3          7     TI       1.945910  4.357141     0.003312   91.157103
# 4          8     TI       2.079442  5.543859     0.003482  257.683183
# 5          9     TI       2.197225  6.907739     0.003631  728.419629
# 0          4  bc-MC            NaN       NaN          NaN         NaN
# 1          5  bc-MC            NaN       NaN          NaN         NaN
# 2          6  bc-MC            NaN       NaN          NaN         NaN
# 3          7  bc-MC            NaN       NaN          NaN         NaN

# %%
df_TI["log_dim_state"] = np.log(df_TI["dim_state"])
df_MC["log_dim_state"] = np.log(df_MC["dim_state"])
df_TI["log_time"] = np.log(df_TI["time"])
df_MC["log_time"] = np.log(df_MC["time"])

reg_MC = smf.ols(formula='mean_E ~ log_dim_state', data=df_MC).fit()
print(reg_MC.summary())
df_MC["mean_E_pred"] = reg_MC.predict()
reg_MC = smf.ols(formula='log_time ~ dim_state', data=df_MC).fit()
print(reg_MC.summary())
df_MC["time_pred"] = np.exp(reg_MC.predict())

reg_TI = smf.ols(formula='mean_E ~ log_dim_state', data=df_TI).fit()
print(reg_TI.summary())
df_TI["mean_E_pred"] = reg_TI.predict()
reg_TI = smf.ols(formula='log_time ~ dim_state', data=df_TI).fit()
print(reg_TI.summary())
df_TI["time_pred"] = np.exp(reg_TI.predict())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 mean_E   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.073
# Method:                 Least Squares   F-statistic:                    0.1207
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):              0.734
# Time:                        02:31:45   Log-Likelihood:                 69.099
# No. Observations:                  14   AIC:                            -134.2
# Df Residuals:                      12   BIC:                            -132.9
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0035      0.003      1.296      0.219      -0.002       0.009
# log_dim_state     0.0004      0.001      0.347      0.734      -0.002       0.003
# ==============================================================================
# Omnibus:                       10.692   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                6.572
# Skew:                           1.516   Prob(JB):                       0.0374
# Kurtosis:                       4.441   Cond. No.                         14.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               log_time   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.048
# Method:                 Least Squares   F-statistic:                    0.4044
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):              0.537
# Time:                        02:31:45   Log-Likelihood:                 29.513
# No. Observations:                  14   AIC:                            -55.03
# Df Residuals:                      12   BIC:                            -53.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4692      0.024    146.545      0.000       3.418       3.521
# dim_state      0.0013      0.002      0.636      0.537      -0.003       0.006
# ==============================================================================
# Omnibus:                        2.292   Durbin-Watson:                   2.253
# Prob(Omnibus):                  0.318   Jarque-Bera (JB):                0.980
# Skew:                          -0.645   Prob(JB):                        0.613
# Kurtosis:                       3.134   Cond. No.                         31.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 mean_E   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     102.6
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           0.000534
# Time:                        02:31:45   Log-Likelihood:                 48.957
# No. Observations:                   6   AIC:                            -93.91
# Df Residuals:                       4   BIC:                            -94.33
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.0008      0.000      3.617      0.022       0.000       0.001
# log_dim_state     0.0013      0.000     10.131      0.001       0.001       0.002
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.100
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                2.934
# Skew:                          -1.644   Prob(JB):                        0.231
# Kurtosis:                       3.961   Cond. No.                         16.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               log_time   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     75.58
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           0.000964
# Time:                        02:31:45   Log-Likelihood:                -3.1388
# No. Observations:                   6   AIC:                             10.28
# Df Residuals:                       4   BIC:                             9.861
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.7614      0.803     -3.438      0.026      -4.992      -0.531
# dim_state      1.0391      0.120      8.694      0.001       0.707       1.371
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.868
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.295
# Skew:                           0.316   Prob(JB):                        0.863
# Kurtosis:                       2.116   Cond. No.                         27.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /home/julien/.local/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/julien/.local/lib/python3.8/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /home/julien/.local/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /home/julien/.local/lib/python3.8/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
n = len(df_TI["dim_state"])
data = df_TI["dim_state"].values
cmap = plt.get_cmap('viridis', np.max(data) - np.min(data) + 1)
# set limits .5 outside true range

p = plt.scatter(df_TI["time"], df_TI["mean_E"], c=list(df_TI["dim_state"].values), cmap=cmap, s=200, label="Time Iteration")
plt.scatter(df_MC["time"], df_MC["mean_E"], c=list(df_MC["dim_state"].values), cmap=cmap, s=200, marker="X", label="bc-MC")
# Fitted values
plt.plot(df_MC["time_pred"], df_MC["mean_E_pred"])
plt.plot(df_TI["time_pred"], df_TI["mean_E_pred"])
plt.xlabel("Elapsed time (sec)")
plt.ylabel("Euler error")
#plt.xscale('log')
plt.xscale('log')
plt.legend()
#plt.colorbar()
# tell the colorbar to tick at integers
cax = plt.colorbar(p, ticks=np.arange(np.min(data), np.max(data) + 1))
cax.set_label('Dimension of the state variable')
               
figname = output_folder + 'Euler_error_time_TI_&_MC_log.png'
plt.tight_layout()
plt.savefig(figname)
plt.show()

# %%
plot_scale = 1.25
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)

fig, (ax1, ax2) = plt.subplots(1, 2)
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE

# Loss AIO
linestyle_TI = "-."
linestyle_MC = "--"
color_TI = "blue"
color_MC = "green"

# Time
ax1.plot(df_TI["dim_state"], df_TI["time"], label="TI", linestyle=linestyle_TI, color=color_TI)
ax1.plot(df_MC["dim_state"], df_MC["time"], label="bc-MC", linestyle=linestyle_MC, color=color_MC)
ax1.set_title('Elapsed time (sec) & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax1.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax1.set_ylabel("Elapsed time (sec)",fontsize=MEDIUM_SIZE)
ax1.legend()

# Accuracy
ax2.plot(df_TI["dim_state"], df_TI["mean_E"], label="TI", linestyle=linestyle_TI, color=color_TI)
ax2.plot(df_MC["dim_state"], df_MC["mean_E"], label="bc-MC", linestyle=linestyle_MC, color=color_MC)
ax2.set_title('Euler error & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax2.set_xlabel("Euler error",fontsize=MEDIUM_SIZE)
ax2.set_ylabel("Euler error",fontsize=MEDIUM_SIZE)
ax2.legend()

ax1.set_yscale('log')


fig.tight_layout()

figname = output_folder + 'Euler_error_time_TI_&_MC_separated_linear.png'
plt.savefig(figname)
plt.show()

# %%
plot_scale = 1.25
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE

# Loss AIO
linestyle_TI = "-."
linestyle_MC = "--"
color_TI = "blue"
color_MC = "green"

# Time
ax1.plot(df_TI["dim_state"], df_TI["time"], label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
ax1.plot(df_MC["dim_state"], df_MC["time"], label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
ax1.set_title('Elapsed time (sec) & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax1.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax1.set_ylabel("Elapsed time (sec)",fontsize=MEDIUM_SIZE)
ax1.legend()

# Accuracy
ax2.plot(df_TI["dim_state"], df_TI["mean_E"], label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
ax2.plot(df_MC["dim_state"], df_MC["mean_E"], label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
ax2.set_title('Euler error & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax2.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax2.set_ylabel("Euler error",fontsize=MEDIUM_SIZE)
ax2.legend()

# Error * time
desired_accuracy = 0.001
desired_time = 100 #in sec
ax3.plot(df_TI["dim_state"], df_TI["mean_E"]*df_TI["time"]/desired_time, label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
# Loss Monte Carlo
ax3.plot(df_MC["dim_state"], df_MC["mean_E"]*df_MC["time"]/desired_time, label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
ax3.set_title('Predicted Euler error (100 sec) & dim. of the state variable',fontsize=MEDIUM_SIZE)
ax3.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax3.set_ylabel("Predicted Euler error (100 sec)",fontsize=MEDIUM_SIZE)
ax3.legend()

ax1.set_yscale('log')
ax3.set_yscale('log')

fig.tight_layout()

figname = output_folder + 'Euler_error_time_TI_&_MC_separated_linear_2.png'
plt.savefig(figname, dpi=dpi_chosen)
plt.show()

# %%
# Generate a color palette with 4 colors
palette = sns.color_palette("husl", 4)

# Print the RGB values of the colors
for i, color in enumerate(palette):
    print(f"Color {i+1}: {color}")

# Plot the colors
sns.palplot(palette)
plt.show()
# Out:
# Color 1: (0.9677975592919913, 0.44127456009157356, 0.5358103155058701)
# Color 2: (0.5920891529639701, 0.6418467016378244, 0.1935069134991043)
# Color 3: (0.21044753832183283, 0.6773105080456748, 0.6433941168468681)
# Color 4: (0.6423044349219739, 0.5497680051256467, 0.9582651433656727)

# %%
truncate_plot = False

if truncate_plot == True:
    df_TI_sparse_selected = df_TI_sparse[df_TI_sparse["dim_state"].isin(df_TI["dim_state"])]
    df_TI_a_sparse_selected = df_TI_a_sparse[df_TI_a_sparse["dim_state"].isin(df_TI["dim_state"])]
else:
    df_TI_sparse_selected = df_TI_sparse
    df_TI_a_sparse_selected = df_TI_a_sparse

# %%
plot_scale = 1.25
plt.rcParams["figure.figsize"] = (plot_scale*16, plot_scale*9)

fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE

# Loss AIO
linestyle_TI = "-."
linestyle_MC = "--"
linestyle_TI_sparse = "solid"
linestyle_TI_a_sparse = "dotted"
color_TI = palette[0] #"blue"
color_MC = palette[1] #"green"
color_TI_sparse = palette[2] 
color_TI_a_sparse = palette[3]

# Time Iteration Dense Grid
ax1.plot(df_TI["dim_state"], df_TI["time"], label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
# bc-MC
ax1.plot(df_MC["dim_state"], df_MC["time"], label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
# Time Iteation sparse grid
ax1.plot(df_TI_sparse_selected["dim_state"], df_TI_sparse_selected["time"], label="TI Sparse", linestyle=linestyle_TI_sparse, color=color_TI_sparse, linewidth=linewidth_chosen)
# Time Iteation a-sparse grid
ax1.plot(df_TI_a_sparse_selected["dim_state"], df_TI_a_sparse_selected["time"], label="TI A-Sparse", linestyle=linestyle_TI_a_sparse, color=color_TI_a_sparse, linewidth=linewidth_chosen)

ax1.set_title('Elapsed time (sec) & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax1.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax1.set_ylabel("Elapsed time (sec)",fontsize=MEDIUM_SIZE)
ax1.legend()

# Accuracy
ax2.plot(df_TI["dim_state"], df_TI["mean_E"], label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
# bc-MC
ax2.plot(df_MC["dim_state"], df_MC["mean_E"], label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
# Time Iteation sparse grid
ax2.plot(df_TI_sparse_selected["dim_state"], df_TI_sparse_selected["mean_E"], label="TI Sparse", linestyle=linestyle_TI_sparse, color=color_TI_sparse, linewidth=linewidth_chosen)
# Time Iteation a-sparse grid
ax2.plot(df_TI_a_sparse_selected["dim_state"], df_TI_a_sparse_selected["mean_E"], label="TI A-Sparse", linestyle=linestyle_TI_a_sparse, color=color_TI_a_sparse, linewidth=linewidth_chosen)

ax2.set_title('Euler error & dimension of the state variable',fontsize=MEDIUM_SIZE)
ax2.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax2.set_ylabel("Euler error",fontsize=MEDIUM_SIZE)
ax2.legend()

# Error * time
desired_accuracy = 0.001
desired_time = 100 #in sec
# Time iteration dense grid
ax3.plot(df_TI["dim_state"], df_TI["mean_E"]*df_TI["time"]/desired_time, label="TI", linestyle=linestyle_TI, color=color_TI, linewidth=linewidth_chosen)
# Loss Monte Carlo
ax3.plot(df_MC["dim_state"], df_MC["mean_E"]*df_MC["time"]/desired_time, label="bc-MC", linestyle=linestyle_MC, color=color_MC, linewidth=linewidth_chosen)
# Time iteration sparse
ax3.plot(df_TI_sparse_selected["dim_state"], df_TI_sparse_selected["mean_E"]*df_TI_sparse_selected["time"]/desired_time, label="TI Sparse", linestyle=linestyle_TI_sparse, color=color_TI_sparse, linewidth=linewidth_chosen)
# Time iteration adaptive sparse grid
ax3.plot(df_TI_a_sparse_selected["dim_state"], df_TI_a_sparse_selected["mean_E"]*df_TI_a_sparse_selected["time"]/desired_time, label="TI A-Sparse", linestyle=linestyle_TI_a_sparse, color=color_TI_a_sparse, linewidth=linewidth_chosen)

ax3.set_title('Predicted Euler error (100 sec) & dim. of the state variable',fontsize=MEDIUM_SIZE)
ax3.set_xlabel("Dimension state",fontsize=MEDIUM_SIZE)
ax3.set_ylabel("Predicted Euler error (100 sec)",fontsize=MEDIUM_SIZE)
ax3.legend()

ax1.set_yscale('log')
ax3.set_yscale('log')

fig.tight_layout()

figname = output_folder + 'Euler_error_time_TI_&_MC_separated_linear_3.png'
plt.savefig(figname, dpi=dpi_chosen)
plt.show()

# %% [markdown]
# ---
#
# # Solve really high dimensional models
